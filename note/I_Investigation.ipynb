# %% [markdown]
# ### Investigation

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../data/cleaned_data/2re_semi_cleaned_data.csv')

# %%
data.head()
# Out:
#   senior_citizen partner dependents  tenure    multiple_lines  \
# 0             No     Yes         No       1  No phone service
# 1             No      No         No      34                No
# 2             No      No         No       2                No
# 3             No      No         No      45  No phone service
# 4             No      No         No       2                No
#
#   internet_service online_security online_backup device_protection  \
# 0              DSL              No           Yes                No
# 1              DSL             Yes            No               Yes
# 2              DSL             Yes           Yes                No
# 3              DSL             Yes            No               Yes
# 4      Fiber optic              No            No                No
#
#   tech_support streaming_tv streaming_movies        contract  \
# 0           No           No               No  Month-to-month
# 1           No           No               No        One year
# ...

# %%
yes_count = data['churn'].value_counts()['Yes']
print("Number of 'Yes' values in the 'churn' column:", yes_count)
# Out:
# Number of 'Yes' values in the 'churn' column: 1869

# %%
churned_data = data[data['churn'] == 'Yes']

# %%
# Out:
#      senior_citizen partner dependents  tenure multiple_lines  \
# 2                No      No         No       2             No
# 4                No      No         No       2             No
# 5                No      No         No       8            Yes
# 8                No     Yes         No      28            Yes
# 13               No      No         No      49            Yes
# ...             ...     ...        ...     ...            ...
# 7010             No      No         No      12             No
# 7015             No      No         No       9             No
# 7021            Yes      No         No       1            Yes
# 7023             No      No         No      67            Yes
# 7030            Yes     Yes         No       4            Yes
#
#      internet_service online_security online_backup device_protection  \
# 2                 DSL             Yes           Yes                No
# 4         Fiber optic              No            No                No
# ...

# %%
filtered_data = churned_data[(churned_data['total_charges'] >= 135) & (churned_data['total_charges'] <= 2331)]

# %%
filtered_data2 = filtered_data[(filtered_data['monthly_charges'] >= 55) & (filtered_data['monthly_charges'] <= 94)]

# %%
filtered_data2.shape
# Out:
# (573, 18)

# %%
573/1869
# Out:
# 0.30658105939004815

# %%
filtered_data2['contract'].value_counts()
# Out:
# contract
# Month-to-month    558
# One year           15
# Name: count, dtype: int64

# %% [markdown]
# ### another investiation

# %%
filtered_data3 = churned_data[(churned_data['monthly_charges'] >= 55) & (churned_data['monthly_charges'] <= 94)]

# %%
filtered_data3['contract'].value_counts()
# Out:
# contract
# Month-to-month    892
# One year           55
# Two year           11
# Name: count, dtype: int64
