# %% [markdown]
# # # F_1_Tuning parameters of RF

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import cohen_kappa_score, make_scorer
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
import pickle
from sklearn.metrics import accuracy_score, classification_report

# %%
#load the files

X_train = pd.read_csv('../data/x_y_data/re_smote/X_resampled.csv')
y_train = pd.read_csv('../data/x_y_data/re_smote/y_resampled.csv')
X_test = pd.read_csv('../data/x_y_data/re_smote/X_test.csv')
y_test = pd.read_csv('../data/x_y_data/re_smote/y_test.csv')
data = pd.read_csv('../data/cleaned_data/cleaned_data.csv')

# %%
y_train.loc[y_train['churn'] == 'Yes', 'churn'] = 1
y_train.loc[y_train['churn'] == 'No', 'churn'] = 0
y_train['churn'].value_counts()
# Out:
# churn
# 1    4130
# 0    4130
# Name: count, dtype: int64

# %%
y_train['churn'] =y_train['churn'].astype('int64')
y_train['churn'].dtypes
# Out:
# dtype('int64')

# %%
y_test.loc[y_test['churn'] == 'Yes', 'churn'] = 1
y_test.loc[y_test['churn'] == 'No', 'churn'] = 0
y_test['churn'].value_counts()
# Out:
# churn
# 0    1033
# 1     374
# Name: count, dtype: int64

# %%
y_test['churn'] =y_test['churn'].astype('int64')
y_test['churn'].dtypes
# Out:
# dtype('int64')

# %%
#set the high-parameter
import warnings
from tqdm.auto import tqdm

# Disable warnings
warnings.filterwarnings("ignore")

param_grid = {
    'n_estimators': [75, 100, 125,150],
    'criterion': ['gini', 'entropy'],
    'min_samples_split': [2, 3],
    'min_samples_leaf': [1, 2],
    'max_depth': [5, 10,15,20],
    'max_features': ['sqrt']  # round(sqrt(#cols))
}

rf = RandomForestClassifier(random_state=12345)

kappa_scorer = make_scorer(cohen_kappa_score)

# Disable tqdm progress bar and set mininterval to suppress messages
with tqdm(total=600, mininterval=1e-9) as pbar:
    grid_search = GridSearchCV(rf, param_grid, cv=5, return_train_score=True,
                               n_jobs=-1, verbose=20, scoring=kappa_scorer)
    grid_search.fit(X_train, y_train)
    pbar.update()  # Make sure progress bar completes

# Enable warnings again
warnings.filterwarnings("default")

grid_search.best_params_  # To check the best set of parameters returned
# Out:
#   0%|          | 0/600 [00:00<?, ?it/s]
# Fitting 5 folds for each of 128 candidates, totalling 640 fits
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# ...
# [CV 3/5; 9/128] START criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=75
# [CV 3/5; 9/128] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=75;, score=(train=0.566, test=0.536) total time=   2.5s
# [CV 4/5; 10/128] START criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 4/5; 10/128] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.565, test=0.531) total time=   3.1s
# [CV 2/5; 12/128] START criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150
# [CV 2/5; 12/128] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=(train=0.569, test=0.548) total time=   4.4s
# [CV 5/5; 13/128] START criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75
# [CV 5/5; 13/128] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75;, score=(train=0.557, test=0.587) total time=   2.1s
# [CV 3/5; 15/128] START criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125
# [CV 3/5; 15/128] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125;, score=(train=0.567, test=0.546) total time=   4.7s
# [CV 1/5; 17/128] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75
# [CV 1/5; 17/128] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75;, score=(train=0.810, test=0.561) total time=   6.4s
# [CV 2/5; 18/128] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 2/5; 18/128] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.801, test=0.625) total time=   6.4s
# [CV 5/5; 19/128] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=125
# [CV 5/5; 19/128] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=125;, score=(train=0.775, test=0.748) total time=   9.8s
# [CV 3/5; 21/128] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=75
# [CV 3/5; 21/128] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=75;, score=(train=0.773, test=0.692) total time=   3.4s
# [CV 5/5; 22/128] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100
# [CV 5/5; 22/128] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100;, score=(train=0.768, test=0.743) total time=   5.7s
# [CV 3/5; 24/128] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150
# [CV 3/5; 24/128] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150;, score=(train=0.776, test=0.700) total time=   7.9s
# [CV 2/5; 26/128] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 2/5; 26/128] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.781, test=0.623) total time=   4.1s
# [CV 5/5; 27/128] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=125
# [CV 5/5; 27/128] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=125;, score=(train=0.749, test=0.737) total time=   4.7s
# [CV 3/5; 29/128] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75
# [CV 3/5; 29/128] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75;, score=(train=0.750, test=0.690) total time=   3.0s
# [CV 4/5; 30/128] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100
# [CV 4/5; 30/128] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100;, score=(train=0.745, test=0.715) total time=   7.2s
# [CV 2/5; 32/128] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150
# [CV 2/5; 32/128] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150;, score=(train=0.780, test=0.621) total time=   7.8s
# [CV 5/5; 33/128] START criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75
# [CV 5/5; 33/128] END criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75;, score=(train=0.932, test=0.794) total time=   6.4s
# [CV 3/5; 35/128] START criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=125
# [CV 3/5; 35/128] END criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=125;, score=(train=0.934, test=0.757) total time=  10.5s
# [CV 1/5; 37/128] START criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=75
# [CV 1/5; 37/128] END criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=75;, score=(train=0.926, test=0.576) total time=   5.4s
# [CV 4/5; 37/128] START criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=75
# [CV 4/5; 37/128] END criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=75;, score=(train=0.917, test=0.780) total time=   5.9s
# [CV 2/5; 39/128] START criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125
# [CV 2/5; 39/128] END criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125;, score=(train=0.923, test=0.625) total time=   5.3s
# [CV 5/5; 40/128] START criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150
# [CV 5/5; 40/128] END criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150;, score=(train=0.914, test=0.792) total time=   5.3s
# [CV 2/5; 43/128] START criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=125
# [CV 2/5; 43/128] END criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=125;, score=(train=0.870, test=0.626) total time=   4.1s
# [CV 5/5; 44/128] START criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150
# [CV 5/5; 44/128] END criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=(train=0.849, test=0.774) total time=   4.6s
# [CV 1/5; 47/128] START criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125
# [CV 1/5; 47/128] END criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125;, score=(train=0.881, test=0.557) total time=   4.1s
# [CV 4/5; 48/128] START criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150
# [CV 4/5; 48/128] END criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150;, score=(train=0.851, test=0.762) total time=   4.7s
# [CV 4/5; 50/128] START criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 4/5; 50/128] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.982, test=0.797) total time=   4.2s
# [CV 2/5; 52/128] START criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150
# [CV 2/5; 52/128] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=(train=0.982, test=0.625) total time=   6.5s
# [CV 1/5; 54/128] START criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100
# [CV 1/5; 54/128] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100;, score=(train=0.973, test=0.594) total time=   4.2s
# [CV 4/5; 55/128] START criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125
# [CV 4/5; 55/128] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125;, score=(train=0.968, test=0.801) total time=   6.3s
# [CV 2/5; 57/128] START criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=75
# [CV 2/5; 57/128] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=75;, score=(train=0.894, test=0.615) total time=   2.9s
# [CV 3/5; 58/128] START criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 3/5; 58/128] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.874, test=0.730) total time=   3.6s
# [CV 1/5; 60/128] START criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150
# [CV 1/5; 60/128] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=(train=0.900, test=0.564) total time=   5.6s
# [CV 5/5; 61/128] START criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75
# [CV 5/5; 61/128] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75;, score=(train=0.867, test=0.766) total time=   3.3s
# [CV 3/5; 63/128] START criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125
# [CV 3/5; 63/128] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125;, score=(train=0.874, test=0.725) total time=   6.6s
# [CV 1/5; 65/128] START criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75
# [CV 1/5; 65/128] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75;, score=(train=0.594, test=0.529) total time=   2.3s
# [CV 3/5; 65/128] START criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75
# [CV 3/5; 65/128] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75;, score=(train=0.562, test=0.547) total time=   2.6s
# [CV 3/5; 66/128] START criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 3/5; 66/128] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.565, test=0.548) total time=   2.6s
# [CV 1/5; 68/128] START criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150
# [CV 1/5; 68/128] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=(train=0.593, test=0.533) total time=   4.1s
# [CV 4/5; 69/128] START criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=75
# [CV 4/5; 69/128] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=75;, score=(train=0.562, test=0.546) total time=   1.7s
# [CV 1/5; 71/128] START criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125
# [CV 1/5; 71/128] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125;, score=(train=0.594, test=0.529) total time=   2.8s
# [CV 4/5; 72/128] START criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150
# [CV 4/5; 72/128] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150;, score=(train=0.562, test=0.539) total time=   3.3s
# [CV 5/5; 74/128] START criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 5/5; 74/128] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.556, test=0.590) total time=   2.1s
# [CV 3/5; 76/128] START criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150
# [CV 3/5; 76/128] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=(train=0.567, test=0.542) total time=   3.0s
# [CV 2/5; 78/128] START criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100
# [CV 2/5; 78/128] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100;, score=(train=0.573, test=0.550) total time=   2.0s
# [CV 5/5; 79/128] START criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125
# [CV 5/5; 79/128] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125;, score=(train=0.555, test=0.584) total time=   2.5s
# [CV 3/5; 81/128] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75
# [CV 3/5; 81/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75;, score=(train=0.769, test=0.689) total time=   2.7s
# [CV 1/5; 83/128] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=125
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# {'criterion': 'entropy',
#  'max_depth': 20,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 150}

# %% [markdown]
# ##### The parameter
# {'criterion': 'entropy',
#  'max_depth': 20,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 150} was chosen.

# %% [markdown]
# ####  Cross validation socre - Kappa-

# %%
rf1= RandomForestClassifier(criterion= 'entropy',
 max_depth= 20,
 max_features= 'sqrt',
 min_samples_leaf= 1,
 min_samples_split= 2,
 n_estimators= 150)

results = []
kfold = KFold(n_splits=10, shuffle=False)
cv_results = cross_val_score(rf1, X_train, y_train, cv=kfold, scoring=kappa_scorer)

results.append(cv_results)
    
msg = f" RF: {cv_results.mean()} ({cv_results.std()})"
print(msg)
# Out:
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [CV 2/5; 1/128] START criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75
# [CV 2/5; 1/128] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75;, score=(train=0.568, test=0.546) total time=   3.2s
# [CV 2/5; 3/128] START criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=125
# [CV 2/5; 3/128] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=125;, score=(train=0.567, test=0.544) total time=   5.1s
# [CV 4/5; 4/128] START criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150
# [CV 4/5; 4/128] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=(train=0.562, test=0.542) total time=   5.5s
# [CV 1/5; 7/128] START criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125
# [CV 1/5; 7/128] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125;, score=(train=0.596, test=0.525) total time=   4.5s
# [CV 4/5; 8/128] START criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150
# [CV 4/5; 8/128] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150;, score=(train=0.562, test=0.542) total time=   4.6s
# [CV 5/5; 10/128] START criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 5/5; 10/128] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.557, test=0.586) total time=   2.9s
# [CV 3/5; 12/128] START criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150
# [CV 3/5; 12/128] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=(train=0.567, test=0.545) total time=   4.4s
# [CV 2/5; 14/128] START criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100
# [CV 2/5; 14/128] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100;, score=(train=0.571, test=0.545) total time=   2.9s
# [CV 5/5; 15/128] START criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125
# [CV 5/5; 15/128] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125;, score=(train=0.556, test=0.591) total time=   6.0s
# [CV 3/5; 17/128] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75
# [CV 3/5; 17/128] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75;, score=(train=0.779, test=0.697) total time=   5.3s
# [CV 1/5; 19/128] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=125
# [CV 1/5; 19/128] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=125;, score=(train=0.806, test=0.561) total time=   9.2s
# [CV 4/5; 20/128] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150
# [CV 4/5; 20/128] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=(train=0.767, test=0.730) total time=   7.8s
# [CV 4/5; 22/128] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100
# [CV 4/5; 22/128] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100;, score=(train=0.763, test=0.728) total time=   5.6s
# [CV 2/5; 24/128] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150
# [CV 2/5; 24/128] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150;, score=(train=0.799, test=0.614) total time=   7.8s
# [CV 1/5; 26/128] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 1/5; 26/128] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.789, test=0.563) total time=   4.2s
# [CV 4/5; 27/128] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=125
# [CV 4/5; 27/128] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=125;, score=(train=0.746, test=0.711) total time=   4.7s
# [CV 2/5; 29/128] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75
# [CV 2/5; 29/128] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75;, score=(train=0.781, test=0.620) total time=   2.9s
# [CV 3/5; 30/128] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100
# [CV 3/5; 30/128] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100;, score=(train=0.751, test=0.684) total time=   7.2s
# [CV 1/5; 32/128] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150
# [CV 1/5; 32/128] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150;, score=(train=0.788, test=0.554) total time=   7.8s
# [CV 4/5; 33/128] START criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75
# [CV 4/5; 33/128] END criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75;, score=(train=0.932, test=0.783) total time=   6.0s
# [CV 2/5; 35/128] START criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=125
# [CV 2/5; 35/128] END criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=125;, score=(train=0.934, test=0.634) total time=  10.4s
# [CV 5/5; 36/128] START criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150
# [CV 5/5; 36/128] END criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=(train=0.930, test=0.800) total time=  11.7s
# [CV 1/5; 39/128] START criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125
# [CV 1/5; 39/128] END criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125;, score=(train=0.925, test=0.576) total time=   5.3s
# [CV 4/5; 40/128] START criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150
# [CV 4/5; 40/128] END criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150;, score=(train=0.915, test=0.791) total time=   5.3s
# [CV 5/5; 42/128] START criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 5/5; 42/128] END criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.847, test=0.771) total time=   3.3s
# [CV 3/5; 44/128] START criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150
# [CV 3/5; 44/128] END criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=(train=0.852, test=0.725) total time=   4.5s
# [CV 3/5; 46/128] START criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100
# [CV 3/5; 46/128] END criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100;, score=(train=0.849, test=0.722) total time=   3.4s
# [CV 1/5; 48/128] START criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150
# [CV 1/5; 48/128] END criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150;, score=(train=0.880, test=0.557) total time=   4.8s
# [CV 4/5; 49/128] START criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75
# [CV 4/5; 49/128] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75;, score=(train=0.981, test=0.793) total time=   2.8s
# [CV 2/5; 51/128] START criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=125
# [CV 2/5; 51/128] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=125;, score=(train=0.982, test=0.625) total time=   5.8s
# [CV 5/5; 52/128] START criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150
# [CV 5/5; 52/128] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=(train=0.985, test=0.799) total time=   5.8s
# [CV 1/5; 55/128] START criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125
# [CV 1/5; 55/128] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125;, score=(train=0.972, test=0.594) total time=   6.3s
# [CV 4/5; 56/128] START criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150
# [CV 4/5; 56/128] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150;, score=(train=0.969, test=0.800) total time=   6.9s
# [CV 2/5; 59/128] START criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=125
# [CV 2/5; 59/128] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=125;, score=(train=0.894, test=0.614) total time=   4.7s
# [CV 5/5; 60/128] START criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150
# [CV 5/5; 60/128] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=(train=0.870, test=0.782) total time=   5.4s
# [CV 1/5; 63/128] START criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125
# [CV 1/5; 63/128] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125;, score=(train=0.898, test=0.567) total time=   6.6s
# [CV 4/5; 64/128] START criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150
# [CV 4/5; 64/128] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150;, score=(train=0.874, test=0.768) total time=   8.2s
# [CV 2/5; 67/128] START criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=125
# [CV 2/5; 67/128] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=125;, score=(train=0.568, test=0.551) total time=   3.4s
# [CV 5/5; 68/128] START criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150
# [CV 5/5; 68/128] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=(train=0.556, test=0.593) total time=   3.4s
# [CV 2/5; 71/128] START criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125
# [CV 2/5; 71/128] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125;, score=(train=0.568, test=0.551) total time=   2.7s
# [CV 5/5; 72/128] START criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150
# [CV 5/5; 72/128] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150;, score=(train=0.557, test=0.591) total time=   3.1s
# [CV 1/5; 75/128] START criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=125
# [CV 1/5; 75/128] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=125;, score=(train=0.594, test=0.530) total time=   2.5s
# [CV 4/5; 76/128] START criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150
# [CV 4/5; 76/128] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=(train=0.555, test=0.534) total time=   3.0s
# [CV 5/5; 78/128] START criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100
# [CV 5/5; 78/128] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100;, score=(train=0.556, test=0.590) total time=   2.0s
# [CV 3/5; 80/128] START criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150
# [CV 3/5; 80/128] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150;, score=(train=0.567, test=0.542) total time=   3.0s
# [CV 1/5; 82/128] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 1/5; 82/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.808, test=0.551) total time=   3.3s
# [CV 4/5; 83/128] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=125
# [CV 4/5; 83/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=125;, score=(train=0.758, test=0.725) total time=   4.8s
# [CV 2/5; 85/128] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=75
# [CV 2/5; 85/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=75;, score=(train=0.794, test=0.609) total time=   3.1s
# [CV 3/5; 86/128] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100
# [CV 3/5; 86/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100;, score=(train=0.763, test=0.701) total time=   3.7s
# [CV 1/5; 88/128] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150
# [CV 1/5; 88/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150;, score=(train=0.804, test=0.553) total time=   6.8s
# [CV 5/5; 89/128] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=75
# [CV 5/5; 89/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=75;, score=(train=0.743, test=0.742) total time=   2.5s
# [CV 2/5; 91/128] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=125
# [CV 2/5; 91/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=125;, score=(train=0.776, test=0.616) total time=   4.2s
# [CV 5/5; 92/128] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150
# [CV 5/5; 92/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=(train=0.742, test=0.749) total time=   5.2s
# [CV 1/5; 95/128] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125
# [CV 1/5; 95/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125;, score=(train=0.785, test=0.553) total time=   5.9s
# [CV 4/5; 96/128] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150
# [CV 4/5; 96/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150;, score=(train=0.742, test=0.724) total time=   6.0s
# [CV 4/5; 98/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 4/5; 98/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.923, test=0.785) total time=   5.8s
# [CV 2/5; 100/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150
# [CV 2/5; 100/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=(train=0.929, test=0.636) total time=   8.5s
# [CV 1/5; 102/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100
# [CV 1/5; 102/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100;, score=(train=0.918, test=0.574) total time=   4.6s
# [CV 4/5; 103/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125
# [CV 4/5; 103/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125;, score=(train=0.912, test=0.786) total time=   7.6s
# [CV 2/5; 105/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=75
# [CV 2/5; 105/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=75;, score=(train=0.875, test=0.627) total time=   4.2s
# [CV 3/5; 106/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 3/5; 106/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.843, test=0.731) total time=   4.3s
# [CV 1/5; 108/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150
# [CV 1/5; 108/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=(train=0.876, test=0.561) total time=   7.8s
# [CV 5/5; 109/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75
# [CV 5/5; 109/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75;, score=(train=0.843, test=0.775) total time=   3.7s
# [CV 3/5; 111/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125
# [CV 3/5; 111/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125;, score=(train=0.847, test=0.734) total time=   6.4s
# [CV 1/5; 113/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75
# [CV 1/5; 113/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75;, score=(train=0.984, test=0.590) total time=   4.6s
# [CV 5/5; 113/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75
# [CV 5/5; 113/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75;, score=(train=0.982, test=0.797) total time=   5.4s
# [CV 3/5; 115/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=125
# [CV 3/5; 115/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=125;, score=(train=0.983, test=0.764) total time=   7.0s
# [CV 1/5; 117/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=75
# [CV 1/5; 117/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=75;, score=(train=0.969, test=0.592) total time=   5.3s
# [CV 4/5; 117/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=75
# [CV 4/5; 117/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=75;, score=(train=0.969, test=0.798) total time=   4.2s
# [CV 2/5; 119/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125
# [CV 2/5; 119/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125;, score=(train=0.969, test=0.627) total time=   8.8s
# [CV 5/5; 120/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150
# [CV 5/5; 120/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150;, score=(train=0.970, test=0.793) total time=   9.8s
# [CV 3/5; 123/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=125
# [CV 3/5; 123/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=125;, score=(train=0.872, test=0.720) total time=   8.1s
# [CV 1/5; 125/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75
# [CV 1/5; 125/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75;, score=(train=0.898, test=0.563) total time=   4.4s
# [CV 4/5; 125/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75
# [CV 4/5; 125/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75;, score=(train=0.877, test=0.774) total time=   3.9s
# [CV 3/5; 127/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125
# [CV 3/5; 127/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125;, score=(train=0.872, test=0.720) total time=   5.4s
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [CV 4/5; 81/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75;, score=(train=0.762, test=0.720) total time=   2.6s
# [CV 2/5; 83/128] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=125
# [CV 2/5; 83/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=125;, score=(train=0.796, test=0.616) total time=   4.5s
# [CV 5/5; 84/128] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150
# [CV 5/5; 84/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=(train=0.763, test=0.747) total time=   5.8s
# [CV 1/5; 87/128] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125
# [CV 1/5; 87/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125;, score=(train=0.803, test=0.559) total time=   5.4s
# [CV 4/5; 88/128] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150
# [CV 4/5; 88/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150;, score=(train=0.756, test=0.732) total time=   5.7s
# [CV 5/5; 90/128] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 5/5; 90/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.741, test=0.747) total time=   3.5s
# [CV 3/5; 92/128] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150
# [CV 3/5; 92/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=(train=0.745, test=0.696) total time=   5.3s
# [CV 2/5; 94/128] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100
# [CV 2/5; 94/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100;, score=(train=0.773, test=0.615) total time=   4.6s
# [CV 5/5; 95/128] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125
# [CV 5/5; 95/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125;, score=(train=0.740, test=0.751) total time=   5.1s
# [CV 3/5; 97/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75
# [CV 3/5; 97/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75;, score=(train=0.927, test=0.762) total time=   4.0s
# [CV 1/5; 99/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=125
# [CV 1/5; 99/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=125;, score=(train=0.924, test=0.570) total time=   7.1s
# [CV 4/5; 100/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150
# [CV 4/5; 100/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=(train=0.926, test=0.776) total time=   8.4s
# [CV 5/5; 102/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100
# [CV 5/5; 102/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100;, score=(train=0.907, test=0.797) total time=   5.5s
# [CV 3/5; 104/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150
# [CV 3/5; 104/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150;, score=(train=0.913, test=0.747) total time=   9.0s
# [CV 2/5; 106/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 2/5; 106/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.872, test=0.623) total time=   3.9s
# [CV 5/5; 107/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=125
# [CV 5/5; 107/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=125;, score=(train=0.845, test=0.774) total time=   7.3s
# [CV 3/5; 109/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75
# [CV 3/5; 109/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75;, score=(train=0.844, test=0.731) total time=   3.6s
# [CV 4/5; 110/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100
# [CV 4/5; 110/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100;, score=(train=0.851, test=0.769) total time=   4.9s
# [CV 2/5; 112/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150
# [CV 2/5; 112/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150;, score=(train=0.874, test=0.627) total time=   7.6s
# [CV 1/5; 114/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 1/5; 114/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.981, test=0.596) total time=   6.5s
# [CV 4/5; 115/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=125
# [CV 4/5; 115/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=125;, score=(train=0.982, test=0.804) total time=   7.6s
# [CV 2/5; 117/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=75
# [CV 2/5; 117/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=75;, score=(train=0.971, test=0.636) total time=   5.3s
# [CV 2/5; 118/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100
# [CV 2/5; 118/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100;, score=(train=0.970, test=0.626) total time=   5.4s
# [CV 5/5; 119/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125
# [CV 5/5; 119/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125;, score=(train=0.969, test=0.804) total time=   8.2s
# [CV 3/5; 121/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=75
# [CV 3/5; 121/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=75;, score=(train=0.871, test=0.726) total time=   5.4s
# [CV 4/5; 122/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 4/5; 122/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.874, test=0.769) total time=   5.1s
# [CV 2/5; 124/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150
# [CV 2/5; 124/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=(train=0.897, test=0.623) total time=  10.4s
# [CV 1/5; 126/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100
# [CV 1/5; 126/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100;, score=(train=0.901, test=0.556) total time=   4.7s
# [CV 4/5; 127/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125
# [CV 4/5; 127/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125;, score=(train=0.875, test=0.776) total time=   5.1s
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [CV 5/5; 80/128] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150;, score=(train=0.555, test=0.592) total time=   3.2s
# [CV 4/5; 82/128] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 4/5; 82/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.759, test=0.728) total time=   3.3s
# [CV 2/5; 84/128] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150
# [CV 2/5; 84/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=(train=0.795, test=0.622) total time=   6.1s
# [CV 1/5; 86/128] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100
# [CV 1/5; 86/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100;, score=(train=0.804, test=0.556) total time=   3.5s
# [CV 4/5; 87/128] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125
# [CV 4/5; 87/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125;, score=(train=0.755, test=0.735) total time=   5.8s
# [CV 2/5; 89/128] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=75
# [CV 2/5; 89/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=75;, score=(train=0.772, test=0.610) total time=   2.8s
# [CV 3/5; 90/128] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 3/5; 90/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.742, test=0.692) total time=   3.4s
# [CV 1/5; 92/128] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150
# [CV 1/5; 92/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=(train=0.784, test=0.556) total time=   5.4s
# [CV 4/5; 93/128] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75
# [CV 4/5; 93/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75;, score=(train=0.741, test=0.718) total time=   2.7s
# [CV 2/5; 95/128] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125
# [CV 2/5; 95/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125;, score=(train=0.776, test=0.616) total time=   5.8s
# [CV 5/5; 96/128] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150
# [CV 5/5; 96/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150;, score=(train=0.742, test=0.749) total time=   6.0s
# [CV 5/5; 98/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 5/5; 98/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.926, test=0.795) total time=   5.8s
# [CV 3/5; 100/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150
# [CV 3/5; 100/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=(train=0.925, test=0.758) total time=   8.7s
# [CV 2/5; 102/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100
# [CV 2/5; 102/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100;, score=(train=0.919, test=0.636) total time=   4.7s
# [CV 5/5; 103/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125
# [CV 5/5; 103/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125;, score=(train=0.907, test=0.795) total time=   7.6s
# [CV 3/5; 105/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=75
# [CV 3/5; 105/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=75;, score=(train=0.844, test=0.731) total time=   4.1s
# [CV 4/5; 106/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 4/5; 106/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.851, test=0.769) total time=   4.6s
# [CV 2/5; 108/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150
# [CV 2/5; 108/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=(train=0.874, test=0.627) total time=   7.8s
# [CV 1/5; 110/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100
# [CV 1/5; 110/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100;, score=(train=0.874, test=0.561) total time=   4.7s
# [CV 4/5; 111/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125
# [CV 4/5; 111/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125;, score=(train=0.853, test=0.774) total time=   6.3s
# [CV 2/5; 113/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75
# [CV 2/5; 113/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75;, score=(train=0.982, test=0.621) total time=   4.7s
# [CV 3/5; 114/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 3/5; 114/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.984, test=0.760) total time=   6.1s
# [CV 1/5; 116/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150
# [CV 1/5; 116/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=(train=0.981, test=0.597) total time=   9.1s
# [CV 5/5; 117/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=75
# [CV 5/5; 117/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=75;, score=(train=0.963, test=0.798) total time=   4.2s
# [CV 3/5; 119/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125
# [CV 3/5; 119/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125;, score=(train=0.969, test=0.760) total time=   9.0s
# [CV 1/5; 121/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=75
# [CV 1/5; 121/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=75;, score=(train=0.898, test=0.563) total time=   4.3s
# [CV 4/5; 121/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=75
# [CV 4/5; 121/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=75;, score=(train=0.877, test=0.774) total time=   4.7s
# [CV 5/5; 122/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 5/5; 122/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.871, test=0.782) total time=   5.8s
# [CV 3/5; 124/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150
# [CV 3/5; 124/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=(train=0.873, test=0.730) total time=   9.8s
# [CV 2/5; 126/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100
# [CV 2/5; 126/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100;, score=(train=0.898, test=0.623) total time=   4.7s
# [CV 5/5; 127/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125
# [CV 5/5; 127/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125;, score=(train=0.870, test=0.783) total time=   4.7s
# [CV 2/5; 86/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100;, score=(train=0.798, test=0.600) total time=   3.6s
# [CV 5/5; 87/128] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125
# [CV 5/5; 87/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125;, score=(train=0.765, test=0.752) total time=   5.7s
# [CV 3/5; 89/128] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=75
# [CV 3/5; 89/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=75;, score=(train=0.742, test=0.685) total time=   2.7s
# [CV 4/5; 90/128] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 4/5; 90/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.740, test=0.718) total time=   3.4s
# [CV 2/5; 92/128] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150
# [CV 2/5; 92/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=(train=0.776, test=0.615) total time=   5.3s
# [CV 1/5; 94/128] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100
# [CV 1/5; 94/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100;, score=(train=0.786, test=0.552) total time=   4.3s
# [CV 4/5; 95/128] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125
# [CV 4/5; 95/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125;, score=(train=0.739, test=0.724) total time=   5.3s
# [CV 2/5; 97/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75
# ...
# [CV 5/5; 93/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75;, score=(train=0.743, test=0.742) total time=   2.8s
# [CV 3/5; 95/128] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125
# [CV 3/5; 95/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125;, score=(train=0.742, test=0.696) total time=   5.8s
# [CV 1/5; 97/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75
# [CV 1/5; 97/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75;, score=(train=0.929, test=0.585) total time=   4.1s
# [CV 1/5; 98/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 1/5; 98/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.925, test=0.581) total time=   5.1s
# [CV 4/5; 99/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=125
# [CV 4/5; 99/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=125;, score=(train=0.924, test=0.780) total time=   6.9s
# [CV 2/5; 101/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=75
# [CV 2/5; 101/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=75;, score=(train=0.919, test=0.623) total time=   4.7s
# [CV 3/5; 102/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100
# [CV 3/5; 102/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100;, score=(train=0.913, test=0.753) total time=   4.8s
# [CV 1/5; 104/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150
# [CV 1/5; 104/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150;, score=(train=0.916, test=0.567) total time=   9.0s
# [CV 5/5; 105/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=75
# [CV 5/5; 105/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=75;, score=(train=0.843, test=0.775) total time=   3.2s
# [CV 3/5; 107/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=125
# [CV 3/5; 107/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=125;, score=(train=0.847, test=0.734) total time=   6.2s
# [CV 1/5; 109/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75
# [CV 1/5; 109/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75;, score=(train=0.873, test=0.571) total time=   4.0s
# [CV 4/5; 109/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75
# [CV 4/5; 109/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75;, score=(train=0.851, test=0.768) total time=   3.8s
# [CV 2/5; 111/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125
# [CV 2/5; 111/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125;, score=(train=0.872, test=0.621) total time=   6.3s
# [CV 5/5; 112/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150
# [CV 5/5; 112/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150;, score=(train=0.844, test=0.776) total time=   8.3s
# [CV 5/5; 114/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 5/5; 114/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.983, test=0.804) total time=   5.8s
# [CV 3/5; 116/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150
# [CV 3/5; 116/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=(train=0.983, test=0.768) total time=  10.1s
# [CV 3/5; 118/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100
# [CV 3/5; 118/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100;, score=(train=0.969, test=0.758) total time=   6.0s
# [CV 1/5; 120/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150
# [CV 1/5; 120/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150;, score=(train=0.969, test=0.581) total time=   9.7s
# [CV 5/5; 121/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=75
# [CV 5/5; 121/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=75;, score=(train=0.870, test=0.777) total time=   4.5s
# [CV 2/5; 123/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=125
# [CV 2/5; 123/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=125;, score=(train=0.899, test=0.622) total time=   8.1s
# [CV 5/5; 124/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150
# [CV 5/5; 124/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=(train=0.872, test=0.782) total time=   8.8s
# [CV 1/5; 127/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125
# [CV 1/5; 127/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125;, score=(train=0.900, test=0.562) total time=   5.4s
# [CV 4/5; 128/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150
# [CV 4/5; 128/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150;, score=(train=0.875, test=0.774) total time=   4.5s
# [CV 3/5; 85/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=75;, score=(train=0.763, test=0.697) total time=   3.0s
# [CV 4/5; 86/128] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100
# [CV 4/5; 86/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100;, score=(train=0.757, test=0.729) total time=   3.7s
# [CV 3/5; 88/128] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150
# [CV 3/5; 88/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150;, score=(train=0.763, test=0.702) total time=   6.9s
# [CV 2/5; 90/128] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 2/5; 90/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.773, test=0.615) total time=   3.3s
# [CV 5/5; 91/128] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=125
# [CV 5/5; 91/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=125;, score=(train=0.740, test=0.751) total time=   4.5s
# [CV 3/5; 93/128] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75
# [CV 3/5; 93/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75;, score=(train=0.742, test=0.685) total time=   2.7s
# [CV 4/5; 94/128] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100
# [CV 4/5; 94/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100;, score=(train=0.740, test=0.718) total time=   4.9s
# [CV 2/5; 96/128] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150
# [CV 2/5; 96/128] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150;, score=(train=0.776, test=0.615) total time=   6.2s
# [CV 5/5; 97/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75
# [CV 5/5; 97/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75;, score=(train=0.926, test=0.795) total time=   3.9s
# [CV 3/5; 99/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=125
# [CV 3/5; 99/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=125;, score=(train=0.926, test=0.762) total time=   6.7s
# [CV 1/5; 101/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=75
# [CV 1/5; 101/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=75;, score=(train=0.917, test=0.563) total time=   4.5s
# [CV 4/5; 101/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=75
# [CV 4/5; 101/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=75;, score=(train=0.909, test=0.783) total time=   3.5s
# [CV 2/5; 103/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125
# [CV 2/5; 103/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125;, score=(train=0.917, test=0.645) total time=   7.3s
# [CV 5/5; 104/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150
# [CV 5/5; 104/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150;, score=(train=0.907, test=0.798) total time=   8.1s
# [CV 2/5; 107/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=125
# [CV 2/5; 107/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=125;, score=(train=0.872, test=0.621) total time=   6.1s
# [CV 5/5; 108/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150
# [CV 5/5; 108/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=(train=0.844, test=0.776) total time=   7.7s
# [CV 1/5; 111/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125
# [CV 1/5; 111/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125;, score=(train=0.877, test=0.564) total time=   6.3s
# [CV 4/5; 112/128] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150
# [CV 4/5; 112/128] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150;, score=(train=0.851, test=0.765) total time=   8.0s
# [CV 4/5; 114/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 4/5; 114/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.982, test=0.795) total time=   5.9s
# [CV 2/5; 116/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150
# [CV 2/5; 116/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=(train=0.983, test=0.626) total time=   9.5s
# [CV 1/5; 118/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100
# [CV 1/5; 118/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100;, score=(train=0.968, test=0.590) total time=   5.4s
# [CV 4/5; 119/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125
# [CV 4/5; 119/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125;, score=(train=0.969, test=0.805) total time=   9.0s
# [CV 2/5; 121/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=75
# [CV 2/5; 121/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=75;, score=(train=0.897, test=0.622) total time=   5.2s
# [CV 3/5; 122/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 3/5; 122/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.871, test=0.729) total time=   4.9s
# [CV 1/5; 124/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150
# [CV 1/5; 124/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=(train=0.902, test=0.564) total time=  10.2s
# [CV 5/5; 125/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75
# [CV 5/5; 125/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75;, score=(train=0.870, test=0.777) total time=   3.9s
# [CV 2/5; 127/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125
# [CV 2/5; 127/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125;, score=(train=0.899, test=0.622) total time=   5.4s
# [CV 5/5; 128/128] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150
# [CV 5/5; 128/128] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150;, score=(train=0.872, test=0.782) total time=   4.3s
#  RF: 0.3978618923629961 (0.2671369739453039)

# %% [markdown]
# ### Variable Importance

# %%
X_train2 = X_train.copy()  
y_train2 = y_train.copy()

rf1= RandomForestClassifier(criterion= 'entropy',
 max_depth= 20,
 max_features= 'sqrt',
 min_samples_leaf= 1,
 min_samples_split= 2,
 n_estimators= 150)

rf_tuned = rf1.fit(X_train2, y_train2)

from sklearn.inspection import permutation_importance


# Calculate permutation feature importances
result = permutation_importance(rf_tuned, X_train2, y_train2, n_repeats=10, random_state=42)

# Sort and display the results
feature_importances = pd.Series(result.importances_mean, index=X_train2.columns).sort_values(ascending=False)

# Plot the feature importances
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 8)) 
sns.barplot(x=feature_importances, y=feature_importances.index)
plt.xlabel('Significance Score Of Variables')
plt.ylabel('Variables')
plt.title("Variable Importance for Random Forest Model")
plt.show()
# Out:
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)

# %%
feature_importances_df = pd.DataFrame(feature_importances)
feature_importances_df.head()
# Out:
#                                 0
# total_charges            0.130387
# monthly_charges          0.053414
# tech_support_No          0.029927
# contract_Two year        0.029818
# contract_Month-to-month  0.025230

# %%
feature_importances_df = feature_importances_df.rename(columns={0:'Significance Score'})
feature_importances_df.head(2)
# Out:
#                  Significance Score
# total_charges              0.130387
# monthly_charges            0.053414

# %%
feature_importances_df.T.to_csv('../data/Significant_Score/RE_T_SMOTE_RF_Significance_Score.csv', index=False)

# %% [markdown]
# ### the classification report

# %%
from sklearn.metrics import confusion_matrix


y_pred = rf1.predict(X_test)

# Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

print("Confusion Matrix:")
display(cm)
# Out:
# Confusion Matrix:
# array([[852, 181],
#        [150, 224]])

# %%
y_pred_df = pd.DataFrame(y_pred)

y_pred_df.value_counts()
# Out:
# 0    1002
# 1     405
# Name: count, dtype: int64

# %%
y_test_df = pd.DataFrame(y_test)

y_test_df.value_counts()
# Out:
# churn
# 0        1033
# 1         374
# Name: count, dtype: int64

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, cohen_kappa_score


y_pred = rf1.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
kappa = cohen_kappa_score(y_test, y_pred)

# Create a DataFrame
metrics_df = pd.DataFrame({
    "Metric": ["Accuracy", "Precision", "Recall", "F1-Score", "Kappa"],
    "Score": [accuracy, precision, recall, f1, kappa]
})

display(metrics_df)
# Out:
#       Metric     Score
# 0   Accuracy  0.764748
# 1  Precision  0.553086
# 2     Recall  0.598930
# 3   F1-Score  0.575096
# 4      Kappa  0.412799

# %%
metrics_df.to_csv('../data/metrics/RE_SMOTE_rf_metrics.csv', index=False)

# %%
#further investigation
