# %% [markdown]
# # E. (rm_null) SMOTE_ Tuning parameters of RF

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
import pickle
from sklearn.metrics import accuracy_score, classification_report

# %%
#load the files

X_train = pd.read_csv('../data/x_y_data/rm_null/X_resampled.csv')
y_train = pd.read_csv('../data/x_y_data/rm_null/y_resampled.csv')
X_test = pd.read_csv('../data/x_y_data/rm_null/X_test.csv')
y_test = pd.read_csv('../data/x_y_data/rm_null/y_test.csv')
data = pd.read_csv('../data/cleaned_data/rm_null_cleaned_data.csv')

# %%
X_train.shape
# Out:
# (7494, 18)

# %%
#set the high-parameter

param_grid = {
    'n_estimators': [50, 100, 150],
    'criterion': ['gini', 'entropy', 'log_loss'],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf' : [1, 2, 5],
    'max_depth':[None,3,5],
    'max_features': ['sqrt', 'log2'] # round(sqrt(#cols))
    }

rf = RandomForestClassifier(random_state=12345)

grid_search = GridSearchCV(rf, param_grid, cv=5,return_train_score=True,n_jobs=-1, verbose = 20)
grid_search.fit(X_train,y_train)
grid_search.best_params_ #To check the best set of parameters returned
# Out:
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# ...
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# {'criterion': 'entropy',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 150}

# %% [markdown]
# ####  Cross validation socre - Accuracy-

# %%
rf1= RandomForestClassifier(criterion= 'entropy',
 max_depth= None,
 max_features= 'sqrt',
 min_samples_leaf= 1,
 min_samples_split= 2,
 n_estimators= 150)

results = []
kfold = KFold(n_splits=10, shuffle=False)
cv_results = cross_val_score(rf1, X_train, y_train, cv=kfold, scoring="accuracy")

results.append(cv_results)
    
msg = f" RF: {cv_results.mean()} ({cv_results.std()})"
print(msg)
# Out:
#  RF: 0.9509073431241657 (0.027705074089183563)

# %%
names = ["accuracy"]
results_dict = {name: result for name, result in zip(names, results)}

# Create the DataFrame using the dictionary
score = pd.DataFrame(results_dict)

# Print the DataFrame
display(score)
# Out:
#    accuracy
# 0  0.913333
# 1  0.936000
# 2  0.922667
# 3  0.932000
# 4  0.917223
# 5  0.969292
# 6  0.986649
# 7  0.971963
# 8  0.981308
# 9  0.978638

# %%
#save the score
score.to_csv('../data/score/rm_null/after_tuning_parameter/RF/rf_cross_val_accuracy.csv', index=False)

# %%
#save the model
rf1.fit(X_train, y_train)

filename = "../models/rm_null_SMOTE_rf.pickle" # Path with filename

with open(filename, "wb") as file:
        pickle.dump(rf1,file)

# %% [markdown]
# #### Cross validation socre - Recall-

# %%
results2 = []
kfold = KFold(n_splits=10, shuffle=False)
cv_results2 = cross_val_score(rf1, X_train, y_train, cv=kfold, scoring="recall")

results2.append(cv_results2)
    
msg2 = f" RF: {cv_results2.mean()} ({cv_results2.std()})"
print(msg2)
# Out:
#  RF: 0.8750597463056577 (0.13414980723481215)

# %%
names2 = ["recall"]
results_dict2 = {name2: result2 for name2, result2 in zip(names2, results2)}

# Create the DataFrame using the dictionary
score2 = pd.DataFrame(results_dict2)

# Print the DataFrame
display(score2)
# Out:
#      recall
# 0  0.576923
# 1  0.846154
# 2  0.705882
# 3  0.914286
# 4  0.806452
# 5  0.986348
# 6  0.983979
# 7  0.971963
# 8  0.978638
# 9  0.979973

# %%
score2.to_csv('../data/score/rm_null/after_tuning_parameter/RF/rf_cross_val_recall.csv', index=False)

# %% [markdown]
# #### Cross validation socre -Precision-

# %%
results3 = []
kfold = KFold(n_splits=10, shuffle=False)
cv_results3 = cross_val_score(rf1, X_train, y_train, cv=kfold, scoring="precision")

results3.append(cv_results3)
    
msg3 = f" RF: {cv_results3.mean()} ({cv_results3.std()})"
print(msg3)
# Out:
#  RF: 0.670543506208685 (0.3292534972348056)

# %%
names3 = ["precision"]
results_dict3 = {name3: result3 for name3, result3 in zip(names3, results3)}

# Create the DataFrame using the dictionary
score3 = pd.DataFrame(results_dict3)

# Print the DataFrame
display(score3)
# Out:
#    precision
# 0   0.217391
# 1   0.432099
# 2   0.356164
# 3   0.410256
# 4   0.313253
# 5   0.976271
# 6   1.000000
# 7   1.000000
# 8   1.000000
# 9   1.000000

# %%
score3.to_csv('../data/score/rm_null/after_tuning_parameter/RF/rf_cross_val_precision.csv', index=False)
# Out:
# [CV 1/5; 405/486] END criterion=log_loss, max_depth=3, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=150;, score=(train=0.801, test=0.782) total time=   1.5s
# [CV 1/5; 407/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 1/5; 407/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.801, test=0.780) total time=   1.1s
# [CV 5/5; 408/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=150
# [CV 5/5; 408/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=(train=0.802, test=0.804) total time=   1.7s
# [CV 3/5; 411/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=150
# [CV 3/5; 411/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=150;, score=(train=0.801, test=0.799) total time=   2.0s
# [CV 4/5; 413/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100
# [CV 4/5; 413/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=0.794, test=0.787) total time=   1.1s
# [CV 2/5; 415/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50
# [CV 2/5; 415/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=(train=0.799, test=0.803) total time=   0.5s
# [CV 5/5; 415/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50
# [CV 5/5; 415/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=(train=0.803, test=0.806) total time=   0.5s
# [CV 1/5; 417/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=150
# [CV 1/5; 417/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=(train=0.801, test=0.781) total time=   1.8s
# [CV 1/5; 419/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 1/5; 419/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=(train=0.801, test=0.780) total time=   1.2s
# [CV 4/5; 420/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=150
# [CV 4/5; 420/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=150;, score=(train=0.796, test=0.787) total time=   1.7s
# [CV 2/5; 423/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=150
# [CV 2/5; 423/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=150;, score=(train=0.798, test=0.801) total time=   1.6s
# [CV 4/5; 425/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=100
# [CV 4/5; 425/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=100;, score=(train=0.794, test=0.787) total time=   1.1s
# [CV 2/5; 427/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=50
# [CV 2/5; 427/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=50;, score=(train=0.799, test=0.805) total time=   0.5s
# [CV 5/5; 427/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=50
# [CV 5/5; 427/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=50;, score=(train=0.803, test=0.806) total time=   0.5s
# [CV 1/5; 429/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=150
# [CV 1/5; 429/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=150;, score=(train=0.801, test=0.782) total time=   1.6s
# [CV 2/5; 431/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=100
# [CV 2/5; 431/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=(train=0.799, test=0.804) total time=   1.1s
# [CV 5/5; 432/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=150
# [CV 5/5; 432/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=150;, score=(train=0.802, test=0.804) total time=   2.4s
# [CV 3/5; 435/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150
# [CV 3/5; 435/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=(train=0.825, test=0.825) total time=   2.4s
# [CV 4/5; 437/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV 4/5; 437/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=(train=0.827, test=0.823) total time=   1.5s
# [CV 2/5; 439/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 2/5; 439/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=(train=0.825, test=0.818) total time=   0.8s
# [CV 5/5; 439/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 5/5; 439/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=(train=0.825, test=0.828) total time=   0.7s
# [CV 1/5; 441/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=150
# [CV 1/5; 441/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=150;, score=(train=0.831, test=0.805) total time=   2.3s
# [CV 1/5; 443/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 1/5; 443/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.836, test=0.807) total time=   2.1s
# [CV 5/5; 444/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150
# [CV 5/5; 444/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=(train=0.825, test=0.826) total time=   3.2s
# [CV 3/5; 447/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=150
# [CV 3/5; 447/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=150;, score=(train=0.826, test=0.825) total time=   2.8s
# [CV 3/5; 449/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100
# [CV 3/5; 449/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=(train=0.829, test=0.824) total time=   1.8s
# [CV 1/5; 451/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=50
# [CV 1/5; 451/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=50;, score=(train=0.832, test=0.800) total time=   0.7s
# [CV 4/5; 451/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=50
# [CV 4/5; 451/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=50;, score=(train=0.821, test=0.823) total time=   0.7s
# [CV 5/5; 452/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=100
# [CV 5/5; 452/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=100;, score=(train=0.830, test=0.832) total time=   1.3s
# [CV 3/5; 454/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=50
# [CV 3/5; 454/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=50;, score=(train=0.822, test=0.810) total time=   0.7s
# [CV 2/5; 455/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=100
# [CV 2/5; 455/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=(train=0.825, test=0.821) total time=   1.5s
# [CV 5/5; 456/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=150
# [CV 5/5; 456/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=150;, score=(train=0.825, test=0.826) total time=   2.0s
# [CV 3/5; 459/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=150
# [CV 3/5; 459/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=150;, score=(train=0.826, test=0.827) total time=   2.0s
# [CV 4/5; 461/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 4/5; 461/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.826, test=0.825) total time=   1.3s
# [CV 2/5; 463/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50
# [CV 2/5; 463/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=(train=0.824, test=0.819) total time=   0.7s
# [CV 5/5; 463/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50
# [CV 5/5; 463/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=(train=0.821, test=0.824) total time=   0.9s
# [CV 1/5; 465/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=150
# [CV 1/5; 465/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=150;, score=(train=0.829, test=0.802) total time=   3.6s
# [CV 1/5; 467/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100
# [CV 1/5; 467/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=0.835, test=0.810) total time=   2.3s
# [CV 4/5; 468/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=150
# [CV 4/5; 468/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=150;, score=(train=0.822, test=0.821) total time=   2.5s
# [CV 2/5; 471/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=150
# [CV 2/5; 471/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=(train=0.825, test=0.820) total time=   2.2s
# [CV 3/5; 473/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 3/5; 473/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=(train=0.832, test=0.829) total time=   1.9s
# [CV 1/5; 475/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=50
# [CV 1/5; 475/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=(train=0.830, test=0.800) total time=   0.9s
# [CV 4/5; 475/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=50
# [CV 4/5; 475/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=(train=0.821, test=0.822) total time=   1.0s
# [CV 5/5; 476/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100
# [CV 5/5; 476/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=(train=0.831, test=0.830) total time=   1.7s
# [CV 3/5; 478/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=50
# [CV 3/5; 478/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=50;, score=(train=0.822, test=0.810) total time=   0.9s
# [CV 1/5; 479/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=100
# [CV 1/5; 479/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=100;, score=(train=0.836, test=0.808) total time=   1.6s
# [CV 4/5; 480/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=150
# [CV 4/5; 480/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=150;, score=(train=0.820, test=0.820) total time=   2.6s
# [CV 2/5; 483/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=150
# [CV 2/5; 483/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=150;, score=(train=0.824, test=0.818) total time=   2.9s
# [CV 3/5; 485/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=100
# [CV 3/5; 485/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=(train=0.831, test=0.825) total time=   2.1s
# [CV 1/5; 410/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV 1/5; 410/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=(train=0.801, test=0.780) total time=   1.2s
# [CV 4/5; 411/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=150
# [CV 4/5; 411/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=150;, score=(train=0.796, test=0.787) total time=   1.9s
# [CV 2/5; 414/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=150
# [CV 2/5; 414/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=150;, score=(train=0.798, test=0.801) total time=   1.5s
# [CV 3/5; 416/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 3/5; 416/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.798, test=0.795) total time=   1.0s
# [CV 1/5; 418/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50
# [CV 1/5; 418/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50;, score=(train=0.802, test=0.780) total time=   0.8s
# [CV 4/5; 418/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50
# [CV 4/5; 418/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50;, score=(train=0.794, test=0.787) total time=   0.6s
# [CV 5/5; 419/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 5/5; 419/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=(train=0.800, test=0.804) total time=   1.2s
# [CV 3/5; 421/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=50
# [CV 3/5; 421/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=(train=0.795, test=0.793) total time=   0.6s
# [CV 1/5; 422/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100
# [CV 1/5; 422/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=(train=0.801, test=0.780) total time=   1.2s
# [CV 4/5; 423/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=150
# [CV 4/5; 423/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=150;, score=(train=0.796, test=0.787) total time=   1.5s
# [CV 2/5; 426/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=150
# [CV 2/5; 426/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=150;, score=(train=0.798, test=0.801) total time=   1.6s
# [CV 3/5; 428/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=100
# [CV 3/5; 428/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=(train=0.798, test=0.795) total time=   1.0s
# [CV 1/5; 430/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=50
# [CV 1/5; 430/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=50;, score=(train=0.802, test=0.780) total time=   0.5s
# [CV 4/5; 430/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=50
# [CV 4/5; 430/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=50;, score=(train=0.794, test=0.787) total time=   0.5s
# [CV 5/5; 431/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=100
# [CV 5/5; 431/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=(train=0.801, test=0.804) total time=   1.2s
# [CV 3/5; 433/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 3/5; 433/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=(train=0.822, test=0.815) total time=   1.0s
# [CV 2/5; 434/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 2/5; 434/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.826, test=0.819) total time=   2.2s
# [CV 1/5; 436/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50
# [CV 1/5; 436/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=(train=0.834, test=0.802) total time=   0.8s
# [CV 4/5; 436/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50
# [CV 4/5; 436/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=(train=0.824, test=0.826) total time=   0.7s
# [CV 5/5; 437/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV 5/5; 437/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=(train=0.828, test=0.830) total time=   1.5s
# [CV 3/5; 439/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 3/5; 439/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=(train=0.820, test=0.809) total time=   0.8s
# [CV 2/5; 440/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100
# [CV 2/5; 440/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=0.827, test=0.821) total time=   1.4s
# [CV 5/5; 441/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=150
# [CV 5/5; 441/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=150;, score=(train=0.824, test=0.826) total time=   2.9s
# [CV 3/5; 444/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150
# [CV 3/5; 444/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=(train=0.825, test=0.825) total time=   2.8s
# [CV 3/5; 446/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 3/5; 446/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=(train=0.832, test=0.829) total time=   2.0s
# [CV 4/5; 447/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=150
# [CV 4/5; 447/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=150;, score=(train=0.821, test=0.823) total time=   2.7s
# [CV 3/5; 450/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=150
# [CV 3/5; 450/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=150;, score=(train=0.825, test=0.828) total time=   2.1s
# [CV 4/5; 452/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=100
# [CV 4/5; 452/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=100;, score=(train=0.825, test=0.822) total time=   1.4s
# [CV 2/5; 454/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=50
# [CV 2/5; 454/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=50;, score=(train=0.824, test=0.818) total time=   0.7s
# [CV 1/5; 455/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=100
# [CV 1/5; 455/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=(train=0.836, test=0.808) total time=   1.5s
# [CV 4/5; 456/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=150
# [CV 4/5; 456/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=150;, score=(train=0.820, test=0.820) total time=   2.0s
# [CV 2/5; 459/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=150
# [CV 2/5; 459/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=150;, score=(train=0.824, test=0.818) total time=   2.0s
# [CV 3/5; 461/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 3/5; 461/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.830, test=0.833) total time=   1.3s
# [CV 1/5; 463/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50
# [CV 1/5; 463/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=(train=0.834, test=0.802) total time=   0.7s
# [CV 4/5; 463/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50
# [CV 4/5; 463/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=(train=0.824, test=0.826) total time=   0.9s
# [CV 5/5; 464/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV 5/5; 464/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=(train=0.828, test=0.830) total time=   2.1s
# [CV 3/5; 466/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 3/5; 466/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=(train=0.820, test=0.809) total time=   1.5s
# [CV 2/5; 467/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100
# [CV 2/5; 467/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=0.827, test=0.821) total time=   2.2s
# [CV 5/5; 468/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=150
# [CV 5/5; 468/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=150;, score=(train=0.824, test=0.826) total time=   2.5s
# [CV 3/5; 471/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=150
# [CV 3/5; 471/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=(train=0.825, test=0.825) total time=   2.3s
# [CV 4/5; 473/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 4/5; 473/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=(train=0.827, test=0.822) total time=   1.9s
# [CV 2/5; 475/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=50
# [CV 2/5; 475/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=(train=0.825, test=0.817) total time=   1.0s
# [CV 5/5; 475/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=50
# [CV 5/5; 475/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=(train=0.825, test=0.828) total time=   0.9s
# [CV 1/5; 477/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=150
# [CV 1/5; 477/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=150;, score=(train=0.830, test=0.807) total time=   2.5s
# [CV 2/5; 479/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=100
# [CV 2/5; 479/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=100;, score=(train=0.825, test=0.821) total time=   1.6s
# [CV 5/5; 480/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=150
# [CV 5/5; 480/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=150;, score=(train=0.825, test=0.826) total time=   2.6s
# [CV 3/5; 483/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=150
# [CV 3/5; 483/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=150;, score=(train=0.826, test=0.827) total time=   2.9s
# [CV 4/5; 485/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=100
# [CV 4/5; 485/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=(train=0.825, test=0.822) total time=   2.0s
# [CV 5/5; 426/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=150
# [CV 5/5; 426/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=150;, score=(train=0.802, test=0.804) total time=   1.5s
# [CV 2/5; 429/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=150
# [CV 2/5; 429/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=150;, score=(train=0.798, test=0.801) total time=   1.6s
# [CV 3/5; 431/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=100
# [CV 3/5; 431/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=(train=0.798, test=0.795) total time=   1.2s
# [CV 2/5; 433/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 2/5; 433/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=(train=0.825, test=0.818) total time=   1.0s
# [CV 5/5; 433/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 5/5; 433/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=(train=0.822, test=0.823) total time=   1.2s
# [CV 1/5; 435/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150
# [CV 1/5; 435/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=(train=0.829, test=0.802) total time=   2.5s
# [CV 1/5; 437/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV 1/5; 437/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=(train=0.836, test=0.805) total time=   1.5s
# [CV 4/5; 438/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=150
# [CV 4/5; 438/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=150;, score=(train=0.822, test=0.824) total time=   2.4s
# [CV 3/5; 441/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=150
# [CV 3/5; 441/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=150;, score=(train=0.826, test=0.827) total time=   2.8s
# [CV 4/5; 443/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 4/5; 443/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.828, test=0.824) total time=   1.9s
# [CV 2/5; 445/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50
# [CV 2/5; 445/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50;, score=(train=0.823, test=0.818) total time=   1.1s
# [CV 1/5; 446/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 1/5; 446/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=(train=0.836, test=0.807) total time=   2.1s
# [CV 1/5; 448/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=50
# [CV 1/5; 448/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=(train=0.830, test=0.800) total time=   0.9s
# [CV 4/5; 448/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=50
# [CV 4/5; 448/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=(train=0.821, test=0.822) total time=   0.9s
# [CV 5/5; 449/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100
# [CV 5/5; 449/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=(train=0.831, test=0.830) total time=   1.8s
# [CV 3/5; 451/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=50
# [CV 3/5; 451/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=50;, score=(train=0.822, test=0.810) total time=   0.7s
# [CV 2/5; 452/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=100
# [CV 2/5; 452/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=100;, score=(train=0.825, test=0.821) total time=   1.3s
# [CV 5/5; 453/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=150
# [CV 5/5; 453/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=150;, score=(train=0.825, test=0.826) total time=   2.0s
# [CV 2/5; 456/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=150
# [CV 2/5; 456/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=150;, score=(train=0.824, test=0.818) total time=   2.0s
# [CV 3/5; 458/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=100
# [CV 3/5; 458/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=(train=0.831, test=0.825) total time=   1.3s
# [CV 1/5; 460/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 1/5; 460/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=(train=0.835, test=0.799) total time=   0.7s
# [CV 5/5; 460/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 5/5; 460/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=(train=0.822, test=0.823) total time=   0.7s
# [CV 5/5; 461/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 5/5; 461/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.830, test=0.830) total time=   1.3s
# [CV 3/5; 463/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50
# [CV 3/5; 463/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=(train=0.823, test=0.815) total time=   0.7s
# [CV 2/5; 464/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV 2/5; 464/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=(train=0.826, test=0.819) total time=   2.0s
# [CV 5/5; 465/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=150
# [CV 5/5; 465/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=150;, score=(train=0.825, test=0.826) total time=   3.9s
# [CV 3/5; 468/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=150
# [CV 3/5; 468/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=150;, score=(train=0.826, test=0.827) total time=   2.7s
# [CV 4/5; 470/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 4/5; 470/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.828, test=0.824) total time=   1.4s
# [CV 2/5; 472/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50
# [CV 2/5; 472/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50;, score=(train=0.823, test=0.818) total time=   0.8s
# [CV 5/5; 472/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50
# [CV 5/5; 472/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50;, score=(train=0.823, test=0.824) total time=   1.0s
# [CV 1/5; 474/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=150
# [CV 1/5; 474/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=150;, score=(train=0.830, test=0.801) total time=   2.8s
# [CV 2/5; 476/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100
# [CV 2/5; 476/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=(train=0.828, test=0.822) total time=   1.7s
# [CV 4/5; 477/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=150
# [CV 4/5; 477/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=150;, score=(train=0.821, test=0.820) total time=   2.6s
# [CV 2/5; 480/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=150
# [CV 2/5; 480/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=150;, score=(train=0.824, test=0.818) total time=   2.6s
# [CV 3/5; 482/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=100
# [CV 3/5; 482/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=(train=0.831, test=0.825) total time=   1.7s
# [CV 1/5; 484/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=50
# [CV 1/5; 484/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=50;, score=(train=0.832, test=0.800) total time=   1.1s
# [CV 4/5; 484/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=50
# [CV 4/5; 484/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=50;, score=(train=0.821, test=0.823) total time=   1.1s
# [CV 5/5; 485/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=100
# [CV 5/5; 485/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=(train=0.830, test=0.832) total time=   2.0s
# [CV 3/5; 403/486] END criterion=log_loss, max_depth=3, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=50;, score=(train=0.795, test=0.793) total time=   0.6s
# [CV 1/5; 404/486] START criterion=log_loss, max_depth=3, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=100
# [CV 1/5; 404/486] END criterion=log_loss, max_depth=3, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=(train=0.801, test=0.781) total time=   1.0s
# [CV 5/5; 405/486] START criterion=log_loss, max_depth=3, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=150
# [CV 5/5; 405/486] END criterion=log_loss, max_depth=3, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=150;, score=(train=0.802, test=0.804) total time=   1.5s
# [CV 3/5; 408/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=150
# [CV 3/5; 408/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=(train=0.801, test=0.799) total time=   1.7s
# [CV 4/5; 410/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV 4/5; 410/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=(train=0.794, test=0.787) total time=   1.2s
# [CV 2/5; 412/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 2/5; 412/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=(train=0.799, test=0.803) total time=   0.7s
# [CV 4/5; 412/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50
# [CV 4/5; 412/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=(train=0.794, test=0.787) total time=   0.6s
# [CV 1/5; 414/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=150
# [CV 1/5; 414/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=150;, score=(train=0.801, test=0.781) total time=   1.6s
# [CV 2/5; 416/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 2/5; 416/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.799, test=0.804) total time=   1.0s
# [CV 5/5; 417/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=150
# [CV 5/5; 417/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=(train=0.802, test=0.804) total time=   1.9s
# [CV 3/5; 420/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=150
# [CV 3/5; 420/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=150;, score=(train=0.801, test=0.799) total time=   1.7s
# [CV 4/5; 422/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100
# [CV 4/5; 422/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=(train=0.794, test=0.787) total time=   1.2s
# [CV 2/5; 424/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=50
# [CV 2/5; 424/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=50;, score=(train=0.799, test=0.805) total time=   0.5s
# [CV 5/5; 424/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=50
# [CV 5/5; 424/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=50;, score=(train=0.803, test=0.806) total time=   0.5s
# [CV 1/5; 426/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=150
# [CV 1/5; 426/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=150;, score=(train=0.801, test=0.782) total time=   1.5s
# [CV 1/5; 428/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=100
# [CV 1/5; 428/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=(train=0.801, test=0.781) total time=   1.1s
# ...
# [CV 1/5; 411/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=150
# [CV 1/5; 411/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=150;, score=(train=0.801, test=0.781) total time=   1.9s
# [CV 1/5; 413/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100
# [CV 1/5; 413/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=0.801, test=0.780) total time=   1.1s
# [CV 4/5; 414/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=150
# [CV 4/5; 414/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=150;, score=(train=0.796, test=0.787) total time=   1.5s
# [CV 2/5; 417/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=150
# [CV 2/5; 417/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=(train=0.798, test=0.801) total time=   1.8s
# [CV 2/5; 419/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 2/5; 419/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=(train=0.799, test=0.804) total time=   1.2s
# [CV 1/5; 421/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=50
# [CV 1/5; 421/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=(train=0.802, test=0.780) total time=   0.6s
# [CV 4/5; 421/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=50
# [CV 4/5; 421/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=(train=0.794, test=0.787) total time=   0.6s
# [CV 5/5; 422/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100
# [CV 5/5; 422/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=(train=0.800, test=0.804) total time=   1.1s
# [CV 3/5; 424/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=50
# [CV 3/5; 424/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=50;, score=(train=0.795, test=0.793) total time=   0.5s
# [CV 1/5; 425/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=100
# [CV 1/5; 425/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=100;, score=(train=0.801, test=0.781) total time=   1.0s
# [CV 4/5; 426/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=150
# [CV 4/5; 426/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=150;, score=(train=0.796, test=0.787) total time=   1.5s
# [CV 3/5; 429/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=150
# [CV 3/5; 429/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=150;, score=(train=0.801, test=0.799) total time=   1.5s
# [CV 4/5; 431/486] START criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=100
# [CV 4/5; 431/486] END criterion=log_loss, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=(train=0.794, test=0.787) total time=   1.2s
# [CV 1/5; 433/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 1/5; 433/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=(train=0.835, test=0.799) total time=   1.0s
# [CV 4/5; 433/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 4/5; 433/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=(train=0.822, test=0.821) total time=   1.2s
# [CV 5/5; 434/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 5/5; 434/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.830, test=0.830) total time=   1.8s
# [CV 3/5; 436/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50
# [CV 3/5; 436/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=(train=0.823, test=0.815) total time=   0.7s
# [CV 2/5; 437/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV 2/5; 437/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=(train=0.826, test=0.819) total time=   1.5s
# [CV 5/5; 438/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=150
# [CV 5/5; 438/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=150;, score=(train=0.825, test=0.826) total time=   2.3s
# [CV 2/5; 441/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=150
# [CV 2/5; 441/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=150;, score=(train=0.824, test=0.819) total time=   2.6s
# [CV 3/5; 443/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 3/5; 443/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.829, test=0.831) total time=   1.9s
# [CV 1/5; 445/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50
# [CV 1/5; 445/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50;, score=(train=0.834, test=0.801) total time=   1.0s
# [CV 4/5; 445/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50
# [CV 4/5; 445/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50;, score=(train=0.824, test=0.826) total time=   1.1s
# [CV 5/5; 446/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 5/5; 446/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=(train=0.828, test=0.830) total time=   2.0s
# [CV 3/5; 448/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=50
# [CV 3/5; 448/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=(train=0.821, test=0.811) total time=   0.9s
# [CV 2/5; 449/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100
# [CV 2/5; 449/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=(train=0.828, test=0.822) total time=   1.8s
# [CV 5/5; 450/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=150
# [CV 5/5; 450/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=150;, score=(train=0.824, test=0.825) total time=   2.0s
# [CV 2/5; 453/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=150
# [CV 2/5; 453/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=150;, score=(train=0.824, test=0.818) total time=   1.9s
# [CV 3/5; 455/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=100
# [CV 3/5; 455/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=(train=0.831, test=0.825) total time=   1.5s
# [CV 1/5; 457/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=50
# [CV 1/5; 457/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=50;, score=(train=0.832, test=0.800) total time=   0.7s
# [CV 5/5; 457/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=50
# [CV 5/5; 457/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=50;, score=(train=0.824, test=0.827) total time=   0.7s
# [CV 5/5; 458/486] START criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=100
# [CV 5/5; 458/486] END criterion=log_loss, max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=(train=0.830, test=0.832) total time=   1.3s
# [CV 3/5; 460/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 3/5; 460/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=(train=0.822, test=0.815) total time=   0.7s
# [CV 2/5; 461/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 2/5; 461/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.826, test=0.819) total time=   1.3s
# [CV 5/5; 462/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=150
# [CV 5/5; 462/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=(train=0.826, test=0.826) total time=   2.5s
# [CV 3/5; 465/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=150
# [CV 3/5; 465/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=150;, score=(train=0.826, test=0.828) total time=   3.9s
# [CV 4/5; 467/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100
# [CV 4/5; 467/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=0.826, test=0.823) total time=   1.9s
# [CV 2/5; 469/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50
# [CV 2/5; 469/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=(train=0.823, test=0.818) total time=   0.9s
# [CV 5/5; 469/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50
# [CV 5/5; 469/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=(train=0.825, test=0.823) total time=   0.7s
# [CV 1/5; 471/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=150
# [CV 1/5; 471/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=(train=0.828, test=0.801) total time=   2.2s
# [CV 1/5; 473/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 1/5; 473/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=(train=0.836, test=0.807) total time=   1.9s
# [CV 4/5; 474/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=150
# [CV 4/5; 474/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=150;, score=(train=0.821, test=0.823) total time=   2.7s
# [CV 2/5; 477/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=150
# [CV 2/5; 477/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=150;, score=(train=0.824, test=0.818) total time=   2.6s
# [CV 3/5; 479/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=100
# [CV 3/5; 479/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=100;, score=(train=0.831, test=0.825) total time=   1.7s
# [CV 1/5; 481/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=50
# [CV 1/5; 481/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=50;, score=(train=0.832, test=0.800) total time=   0.9s
# [CV 4/5; 481/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=50
# [CV 4/5; 481/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=50;, score=(train=0.821, test=0.823) total time=   0.8s
# [CV 5/5; 482/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=100
# [CV 5/5; 482/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=(train=0.830, test=0.832) total time=   1.8s
# [CV 3/5; 484/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=50
# [CV 3/5; 484/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=50;, score=(train=0.822, test=0.810) total time=   1.1s
# [CV 2/5; 485/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=100
# [CV 2/5; 485/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=(train=0.825, test=0.821) total time=   2.1s
# [CV 5/5; 486/486] START criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=150
# [CV 5/5; 486/486] END criterion=log_loss, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=150;, score=(train=0.825, test=0.826) total time=   1.6s

# %% [markdown]
# #### Cross validation socre -F1-

# %%
results4 = []
kfold = KFold(n_splits=10, shuffle=False)
cv_results4 = cross_val_score(rf1, X_train, y_train, cv=kfold, scoring="f1")

results4.append(cv_results4)
    
msg4 = f" RF: {cv_results4.mean()} ({cv_results4.std()})"
print(msg4)
# Out:
#  RF: 0.7280072143709098 (0.26630606102912996)

# %%
names4 = ["f1"]
results_dict4 = {name4: result4 for name4, result4 in zip(names4, results4)}

# Create the DataFrame using the dictionary
score4 = pd.DataFrame(results_dict4)

# Print the DataFrame
display(score4)
# Out:
#          f1
# 0  0.319149
# 1  0.554622
# 2  0.476190
# 3  0.551724
# 4  0.442478
# 5  0.980492
# 6  0.992603
# 7  0.985095
# 8  0.990566
# 9  0.987153

# %%
score4.to_csv('../data/score/rm_null/after_tuning_parameter/RF/rf_cross_val_f1.csv', index=False)

# %% [markdown]
# ### Variable Importance

# %%
X_train2 = pd.read_csv('../data/x_y_data/rm_null/X_resampled.csv')
y_train2 = pd.read_csv('../data/x_y_data/rm_null/y_resampled.csv')


rf_tuned = rf1.fit(X_train2, y_train2)

from sklearn.inspection import permutation_importance


# Calculate permutation feature importances
result = permutation_importance(rf1, X_train2, y_train2, n_repeats=10, random_state=42)

# Sort and display the results
feature_importances = pd.Series(result.importances_mean, index=X_train2.columns).sort_values(ascending=False)

# Plot the feature importances
import matplotlib.pyplot as plt

sns.barplot(x=feature_importances, y=feature_importances.index)
plt.xlabel('Significance Score Of Variables')
plt.ylabel('Variables')
plt.title("Variable Importance for Random Forest Model")
plt.show()

# %% [markdown]
# #####  The level of 'age' is very high, compared to 'KNN'

# %%
feature_importances_df = pd.DataFrame(feature_importances)
feature_importances_df
# Out:
#                                        0
# age                             0.216080
# avg_glucose_level               0.093942
# hypertension                    0.085415
# ever_married                    0.074553
# bmi                             0.063944
# heart_disease                   0.053469
# work_type_Self-employed         0.027996
# smoking_status_never smoked     0.027529
# smoking_status_Unknown          0.024620
# work_type_Govt_job              0.023352
# work_type_Private               0.013544
# smoking_status_formerly smoked  0.013344
# residence_type_Rural            0.010555
# gender_F                        0.006899
# smoking_status_smokes           0.006298
# gender_M                        0.006138
# residence_type_Urban            0.004871
# work_type_Other                 0.000147

# %%
feature_importances_df = feature_importances_df.rename(columns={0:'Significance Score'})
feature_importances_df.head(2)
# Out:
#                    Significance Score
# age                          0.216080
# avg_glucose_level            0.093942

# %%
feature_importances_df.to_csv('../data/score/rm_null/Significant_Score/RF_Significance_Score.csv', index=False)

# %% [markdown]
# ### the classification report

# %%
from sklearn.metrics import confusion_matrix


y_pred = rf1.predict(X_test)

# Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

print("Confusion Matrix:")
display(cm)
# Out:
# Confusion Matrix:
# array([[893,  46],
#        [ 33,   7]])

# %%
y_pred_df = pd.DataFrame(y_pred)

y_pred_df.value_counts()
# Out:
# 0    926
# 1     53
# Name: count, dtype: int64

# %%
y_test_df = pd.DataFrame(y_test)

y_test_df.value_counts()
# Out:
# stroke
# 0         939
# 1          40
# Name: count, dtype: int64

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, cohen_kappa_score


y_pred = rf1.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
kappa = cohen_kappa_score(y_test, y_pred)

# Create a DataFrame
metrics_df = pd.DataFrame({
    "Metric": ["Accuracy", "Precision", "Recall", "F1-Score", "Kappa"],
    "Score": [accuracy, precision, recall, f1, kappa]
})

display(metrics_df)
# Out:
#       Metric     Score
# 0   Accuracy  0.919305
# 1  Precision  0.132075
# 2     Recall  0.175000
# 3   F1-Score  0.150538
# 4      Kappa  0.109047

# %%
metrics_df.to_csv('../data/metrics/rm_null/rf_metrics.csv', index=False)
