# %% [markdown]
# ### D_1. Logistic classification

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import cohen_kappa_score, make_scorer
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
import pickle
from sklearn.metrics import accuracy_score, classification_report

# %%
#load the files

X_train = pd.read_csv('../data/x_y_data/re_smote/down_X_resampled.csv')
y_train = pd.read_csv('../data/x_y_data/re_smote/down_y_resampled.csv')
X_test = pd.read_csv('../data/x_y_data/re_smote/down_X_test.csv')
y_test = pd.read_csv('../data/x_y_data/re_smote/down_y_test.csv')
data = pd.read_csv('../data/cleaned_data/cleaned_data.csv')

# %%
X_train.shape
# Out:
# (2990, 41)

# %% [markdown]
# ### Variable Importance

# %%
lg1= LogisticRegression(penalty = 'l2')

lg_tuned = lg1.fit(X_train, y_train)

from sklearn.inspection import permutation_importance


# Calculate permutation feature importances
result = permutation_importance(lg_tuned, X_train, y_train, n_repeats=10, random_state=42)

# Sort and display the results
feature_importances = pd.Series(result.importances_mean, index=X_train.columns).sort_values(ascending=False)

# Plot the feature importances
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8)) 
sns.barplot(x=feature_importances, y=feature_importances.index)
plt.xlabel('Significance Score Of Variables')
plt.ylabel('Variables')
plt.title("Variable Importance for Logistic Regression  Model")
plt.show()

# %%
#save the model
lg1.fit(X_train, y_train)

filename = "../models/re_down_smote_lg.pickle" # Path with filename

with open(filename, "wb") as file:
        pickle.dump(lg1,file)

# %%
feature_importances_df = pd.DataFrame(feature_importances)
feature_importances_df.head()
# Out:
#                                      0
# total_charges                 0.082676
# internet_service_Fiber optic  0.011639
# contract_Month-to-month       0.009532
# internet_service_DSL          0.006823
# contract_Two year             0.004281

# %%
feature_importances_df
# Out:
#                                                  0
# total_charges                             0.082676
# internet_service_Fiber optic              0.011639
# contract_Month-to-month                   0.009532
# internet_service_DSL                      0.006823
# contract_Two year                         0.004281
# payment_method_Electronic check           0.003177
# streaming_tv_Yes                          0.002441
# payment_method_Credit card (automatic)    0.001037
# online_security_Yes                       0.000836
# online_backup_No                          0.000635
# monthly_charges                           0.000100
# senior_citizen_No                         0.000033
# senior_citizen_Yes                        0.000033
# partner_No                                0.000033
# partner_Yes                               0.000033
# payment_method_Bank transfer (automatic) -0.000067
# contract_One year                        -0.000134
# streaming_tv_No                          -0.000167
# tech_support_Yes                         -0.000301
# paperless_billing_No                     -0.000368
# multiple_lines_No phone service          -0.000435
# online_security_No                       -0.000435
# paperless_billing_Yes                    -0.000535
# tech_support_No                          -0.000803
# device_protection_No                     -0.000836
# streaming_movies_No                      -0.000870
# dependents_No                            -0.001137
# dependents_Yes                           -0.001137
# online_backup_Yes                        -0.001672
# streaming_movies_Yes                     -0.001706
# device_protection_Yes                    -0.002341
# online_security_No internet service      -0.002943
# internet_service_No                      -0.002943
# streaming_movies_No internet service     -0.002943
# tech_support_No internet service         -0.002943
# online_backup_No internet service        -0.002943
# device_protection_No internet service    -0.002943
# streaming_tv_No internet service         -0.002943
# multiple_lines_No                        -0.002977
# payment_method_Mailed check              -0.002977
# multiple_lines_Yes                       -0.004716

# %%
feature_importances_df.T.to_csv('../data/Re_Significant_Score/down_re_LG_Significance_Score.csv', index=False)

# %% [markdown]
# ### the classification report

# %%
from sklearn.metrics import confusion_matrix


y_pred = lg1.predict(X_test)

# Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

print("Confusion Matrix:")
display(cm)
# Out:
# Confusion Matrix:
# array([[745, 288],
#        [ 74, 300]])

# %%
y_pred_df = pd.DataFrame(y_pred)

y_pred_df.value_counts()
# Out:
# No     819
# Yes    588
# Name: count, dtype: int64

# %%
y_test_df = pd.DataFrame(y_test)

y_test_df.value_counts()
# Out:
# churn
# No       1033
# Yes       374
# Name: count, dtype: int64

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, cohen_kappa_score


y_pred = lg1.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, pos_label='Yes')
recall = recall_score(y_test, y_pred, pos_label='Yes')
f1 = f1_score(y_test, y_pred, pos_label='Yes')
kappa = cohen_kappa_score(y_test, y_pred)

# Create a DataFrame
metrics_df = pd.DataFrame({
    "Metric": ["Accuracy", "Precision", "Recall", "F1-Score", "Kappa"],
    "Score": [accuracy, precision, recall, f1, kappa]
})

display(metrics_df)
# Out:
#       Metric     Score
# 0   Accuracy  0.742715
# 1  Precision  0.510204
# 2     Recall  0.802139
# 3   F1-Score  0.623701
# 4      Kappa  0.442565

# %%
metrics_df.to_csv('../data/metrics/RE_down_SMOTE_lg_metrics.csv', index=False)
