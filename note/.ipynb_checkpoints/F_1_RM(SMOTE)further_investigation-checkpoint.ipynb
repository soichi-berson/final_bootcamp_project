# %% [markdown]
# # # F_3_Tuning parameters of RF Further investigation

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import cohen_kappa_score, make_scorer
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
import pickle
from sklearn.metrics import accuracy_score, classification_report

# %%
#load the files

X_train = pd.read_csv('../data/x_y_data/re_smote/X_resampled.csv')
y_train = pd.read_csv('../data/x_y_data/re_smote/y_resampled.csv')
X_test = pd.read_csv('../data/x_y_data/re_smote/X_test.csv')
y_test = pd.read_csv('../data/x_y_data/re_smote/y_test.csv')
data = pd.read_csv('../data/cleaned_data/cleaned_data.csv')

# %%
y_train.loc[y_train['churn'] == 'Yes', 'churn'] = 1
y_train.loc[y_train['churn'] == 'No', 'churn'] = 0
y_train['churn'].value_counts()
# Out:
# churn
# 1    4130
# 0    4130
# Name: count, dtype: int64

# %%
y_train['churn'] =y_train['churn'].astype('int64')
y_train['churn'].dtypes
# Out:
# dtype('int64')

# %%
y_test.loc[y_test['churn'] == 'Yes', 'churn'] = 1
y_test.loc[y_test['churn'] == 'No', 'churn'] = 0
y_test['churn'].value_counts()
# Out:
# churn
# 0    1033
# 1     374
# Name: count, dtype: int64

# %%
y_test['churn'] =y_test['churn'].astype('int64')
y_test['churn'].dtypes
# Out:
# dtype('int64')

# %%
#set the high-parameter
import warnings
from tqdm.auto import tqdm

# Disable warnings
warnings.filterwarnings("ignore")

param_grid = {
    'n_estimators': [75, 100, 125,150, 175],
    'criterion': ['gini', 'entropy'],
    'min_samples_split': [2, 3],
    'min_samples_leaf': [1, 2],
    'max_depth': [5, 10,15,20,25],
    'max_features': ['sqrt']  # round(sqrt(#cols))
}

rf = RandomForestClassifier(random_state=12345)

kappa_scorer = make_scorer(cohen_kappa_score)

# Disable tqdm progress bar and set mininterval to suppress messages
with tqdm(total=600, mininterval=1e-9) as pbar:
    grid_search = GridSearchCV(rf, param_grid, cv=5, return_train_score=True,
                               n_jobs=-1, verbose=20, scoring=kappa_scorer)
    grid_search.fit(X_train, y_train)
    pbar.update()  # Make sure progress bar completes

# Enable warnings again
warnings.filterwarnings("default")

grid_search.best_params_  # To check the best set of parameters returned
# Out:
#   0%|          | 0/600 [00:00<?, ?it/s]
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# ...
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# {'criterion': 'entropy',
#  'max_depth': 20,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 150}

# %%
grid_search.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 20,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 150}
# [CV 2/5; 80/200] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=175;, score=(train=0.895, test=0.627) total time=   5.5s
# [CV 1/5; 82/200] START criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 1/5; 82/200] END criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.997, test=0.587) total time=   3.3s
# [CV 4/5; 83/200] START criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=125
# [CV 4/5; 83/200] END criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=125;, score=(train=0.997, test=0.797) total time=   4.8s
# [CV 2/5; 85/200] START criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=175
# [CV 2/5; 85/200] END criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=175;, score=(train=0.998, test=0.617) total time=   6.0s
# [CV 3/5; 87/200] START criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100
# [CV 3/5; 87/200] END criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100;, score=(train=0.986, test=0.766) total time=   4.1s
# [CV 1/5; 89/200] START criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150
# [CV 1/5; 89/200] END criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150;, score=(train=0.992, test=0.576) total time=   4.9s
# [CV 4/5; 90/200] START criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=175
# [CV 4/5; 90/200] END criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=175;, score=(train=0.991, test=0.795) total time=   6.4s
# [CV 2/5; 93/200] START criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=125
# [CV 2/5; 93/200] END criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=125;, score=(train=0.903, test=0.620) total time=   3.8s
# [CV 5/5; 94/200] START criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150
# [CV 5/5; 94/200] END criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=(train=0.873, test=0.781) total time=   5.3s
# [CV 3/5; 96/200] START criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75
# [CV 3/5; 96/200] END criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75;, score=(train=0.873, test=0.730) total time=   2.2s
# [CV 4/5; 97/200] START criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100
# [CV 4/5; 97/200] END criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100;, score=(train=0.871, test=0.770) total time=   3.0s
# [CV 2/5; 99/200] START criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150
# [CV 2/5; 99/200] END criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150;, score=(train=0.903, test=0.615) total time=   7.7s
# [CV 5/5; 100/200] START criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=175
# [CV 5/5; 100/200] END criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=175;, score=(train=0.873, test=0.778) total time=   5.9s
# [CV 1/5; 104/200] START criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150
# [CV 1/5; 104/200] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=(train=0.593, test=0.533) total time=   2.7s
# [CV 4/5; 105/200] START criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=175
# [CV 4/5; 105/200] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=175;, score=(train=0.561, test=0.539) total time=   2.8s
# [CV 5/5; 107/200] START criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100
# [CV 5/5; 107/200] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100;, score=(train=0.556, test=0.590) total time=120.0min
# [CV 3/5; 109/200] START criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150
# [CV 3/5; 109/200] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150;, score=(train=0.564, test=0.542) total time=   3.6s
# [CV 2/5; 111/200] START criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=75
# [CV 2/5; 111/200] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=75;, score=(train=0.572, test=0.553) total time=   1.0s
# [CV 1/5; 112/200] START criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 1/5; 112/200] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.594, test=0.527) total time=   1.3s
# [CV 4/5; 113/200] START criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=125
# [CV 4/5; 113/200] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=125;, score=(train=0.561, test=0.538) total time=   2.0s
# [CV 2/5; 115/200] START criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=175
# [CV 2/5; 115/200] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=175;, score=(train=0.569, test=0.550) total time=  22.6s
# [CV 5/5; 116/200] START criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75
# [CV 5/5; 116/200] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75;, score=(train=0.557, test=0.586) total time=119.5min
# [CV 2/5; 118/200] START criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125
# [CV 2/5; 118/200] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125;, score=(train=0.567, test=0.550) total time=   2.3s
# [CV 5/5; 119/200] START criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150
# [CV 5/5; 119/200] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150;, score=(train=0.555, test=0.592) total time=   2.2s
# [CV 3/5; 121/200] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75
# [CV 3/5; 121/200] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75;, score=(train=0.769, test=0.689) total time=   1.3s
# [CV 3/5; 122/200] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 3/5; 122/200] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.769, test=0.694) total time=   1.5s
# [CV 1/5; 124/200] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150
# [CV 1/5; 124/200] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=(train=0.805, test=0.558) total time=  21.5s
# [CV 4/5; 125/200] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=175
# [CV 4/5; 125/200] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=175;, score=(train=0.759, test=0.731) total time=103.4min
# [CV 1/5; 128/200] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125
# [CV 1/5; 128/200] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125;, score=(train=0.803, test=0.559) total time=   1.8s
# [CV 4/5; 129/200] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150
# [CV 4/5; 129/200] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150;, score=(train=0.756, test=0.732) total time=   2.7s
# [CV 2/5; 131/200] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=75
# [CV 2/5; 131/200] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=75;, score=(train=0.772, test=0.610) total time=   1.0s
# [CV 2/5; 132/200] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 2/5; 132/200] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.773, test=0.615) total time=  18.9s
# [CV 5/5; 133/200] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=125
# [CV 5/5; 133/200] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=125;, score=(train=0.740, test=0.751) total time=119.7min
# [CV 3/5; 135/200] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=175
# [CV 3/5; 135/200] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=175;, score=(train=0.747, test=0.695) total time=   2.3s
# [CV 3/5; 137/200] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100
# [CV 3/5; 137/200] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100;, score=(train=0.742, test=0.692) total time=   1.4s
# [CV 1/5; 139/200] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150
# [CV 1/5; 139/200] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150;, score=(train=0.784, test=0.556) total time=  27.8s
# [CV 4/5; 140/200] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=175
# [CV 4/5; 140/200] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=175;, score=(train=0.741, test=0.725) total time=63.7min
# [CV 4/5; 142/200] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 4/5; 142/200] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.923, test=0.785) total time=   3.7s
# [CV 3/5; 144/200] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150
# [CV 3/5; 144/200] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=(train=0.925, test=0.758) total time=   4.6s
# [CV 1/5; 146/200] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=75
# [CV 1/5; 146/200] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=75;, score=(train=0.917, test=0.563) total time=   2.7s
# [CV 4/5; 146/200] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=75
# [CV 4/5; 146/200] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=75;, score=(train=0.909, test=0.783) total time=   2.5s
# [CV 5/5; 147/200] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100
# [CV 5/5; 147/200] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100;, score=(train=0.907, test=0.797) total time=   2.9s
# [CV 3/5; 149/200] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150
# [CV 3/5; 149/200] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150;, score=(train=0.913, test=0.747) total time=   5.2s
# [CV 1/5; 151/200] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=75
# [CV 1/5; 151/200] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=75;, score=(train=0.873, test=0.571) total time=   2.6s
# [CV 5/5; 151/200] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=75
# [CV 5/5; 151/200] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=75;, score=(train=0.843, test=0.775) total time=   2.3s
# [CV 1/5; 153/200] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=125
# [CV 1/5; 153/200] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=125;, score=(train=0.877, test=0.564) total time=   4.8s
# [CV 4/5; 154/200] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150
# [CV 4/5; 154/200] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=(train=0.851, test=0.765) total time=   4.8s
# [CV 2/5; 156/200] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75
# [CV 2/5; 156/200] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75;, score=(train=0.875, test=0.627) total time=   2.7s
# [CV 2/5; 157/200] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100
# [CV 2/5; 157/200] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100;, score=(train=0.872, test=0.623) total time=   3.3s
# [CV 5/5; 158/200] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125
# [CV 5/5; 158/200] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125;, score=(train=0.845, test=0.774) total time=   4.5s
# [CV 3/5; 160/200] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=175
# [CV 3/5; 160/200] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=175;, score=(train=0.847, test=0.730) total time=   5.3s
# [CV 2/5; 162/200] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 2/5; 162/200] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.982, test=0.623) total time=   3.7s
# [CV 5/5; 163/200] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=125
# [CV 5/5; 163/200] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=125;, score=(train=0.983, test=0.803) total time=   4.7s
# [CV 3/5; 165/200] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=175
# [CV 3/5; 165/200] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=175;, score=(train=0.982, test=0.768) total time=   6.7s
# [CV 4/5; 167/200] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100
# [CV 4/5; 167/200] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100;, score=(train=0.967, test=0.800) total time=   3.7s
# [CV 2/5; 169/200] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150
# [CV 2/5; 169/200] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150;, score=(train=0.969, test=0.622) total time=   8.6s
# [CV 5/5; 170/200] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=175
# [CV 5/5; 170/200] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=175;, score=(train=0.969, test=0.798) total time=   6.7s
# [CV 3/5; 173/200] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=125
# [CV 3/5; 173/200] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=125;, score=(train=0.872, test=0.720) total time=   3.2s
# [CV 1/5; 175/200] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=175
# [CV 1/5; 175/200] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=175;, score=(train=0.903, test=0.565) total time=   4.9s
# [CV 5/5; 176/200] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75
# [CV 5/5; 176/200] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75;, score=(train=0.870, test=0.777) total time=   2.3s
# [CV 2/5; 178/200] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125
# [CV 2/5; 178/200] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125;, score=(train=0.899, test=0.622) total time=   4.1s
# [CV 5/5; 179/200] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150
# [CV 5/5; 179/200] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150;, score=(train=0.872, test=0.782) total time=   4.4s
# [CV 3/5; 181/200] START criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75
# [CV 3/5; 181/200] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75;, score=(train=0.996, test=0.758) total time=   3.0s
# [CV 3/5; 182/200] START criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 3/5; 182/200] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.996, test=0.762) total time=   3.4s
# [CV 1/5; 184/200] START criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150
# [CV 1/5; 184/200] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=(train=0.997, test=0.598) total time=   5.3s
# [CV 4/5; 185/200] START criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=175
# [CV 4/5; 185/200] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=175;, score=(train=0.997, test=0.803) total time=   6.9s
# [CV 2/5; 188/200] START criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125
# [CV 2/5; 188/200] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125;, score=(train=0.993, test=0.614) total time=   5.8s
# [CV 5/5; 189/200] START criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150
# [CV 5/5; 189/200] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150;, score=(train=0.987, test=0.795) total time=   7.2s
# [CV 3/5; 191/200] START criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=75
# [CV 3/5; 191/200] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=75;, score=(train=0.873, test=0.729) total time=   2.7s
# [CV 3/5; 192/200] START criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 3/5; 192/200] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.873, test=0.732) total time=   4.0s
# [CV 1/5; 194/200] START criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150
# [CV 1/5; 194/200] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=(train=0.908, test=0.561) total time=   5.1s
# [CV 4/5; 195/200] START criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=175
# [CV 4/5; 195/200] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=175;, score=(train=0.880, test=0.777) total time=   6.6s
# [CV 5/5; 197/200] START criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100
# [CV 5/5; 197/200] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100;, score=(train=0.879, test=0.777) total time=   2.9s
# [CV 3/5; 199/200] START criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150
# [CV 3/5; 199/200] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150;, score=(train=0.874, test=0.732) total time=   5.3s
# [CV 3/5; 86/200] END criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=75;, score=(train=0.987, test=0.762) total time=   2.5s
# [CV 2/5; 87/200] START criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100
# [CV 2/5; 87/200] END criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100;, score=(train=0.992, test=0.617) total time=   4.0s
# [CV 5/5; 88/200] START criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125
# [CV 5/5; 88/200] END criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125;, score=(train=0.986, test=0.803) total time=   4.0s
# [CV 3/5; 90/200] START criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=175
# [CV 3/5; 90/200] END criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=175;, score=(train=0.989, test=0.766) total time=   6.7s
# [CV 4/5; 92/200] START criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 4/5; 92/200] END criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.871, test=0.770) total time=   2.9s
# [CV 2/5; 94/200] START criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150
# [CV 2/5; 94/200] END criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=(train=0.903, test=0.615) total time=   5.2s
# [CV 5/5; 95/200] START criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=175
# [CV 5/5; 95/200] END criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=175;, score=(train=0.873, test=0.778) total time=   5.5s
# [CV 1/5; 98/200] START criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125
# [CV 1/5; 98/200] END criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125;, score=(train=0.903, test=0.564) total time=   4.9s
# [CV 4/5; 99/200] START criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150
# [CV 4/5; 99/200] END criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150;, score=(train=0.873, test=0.772) total time=   7.0s
# [CV 2/5; 101/200] START criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75
# [CV 2/5; 101/200] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75;, score=(train=0.573, test=0.554) total time=   1.3s
# [CV 1/5; 102/200] START criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 1/5; 102/200] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.594, test=0.527) total time=   1.6s
# [CV 2/5; 103/200] START criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=125
# [CV 2/5; 103/200] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=125;, score=(train=0.568, test=0.551) total time=   2.1s
# [CV 5/5; 104/200] START criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150
# [CV 5/5; 104/200] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=(train=0.556, test=0.593) total time=   2.6s
# [CV 3/5; 106/200] START criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=75
# [CV 3/5; 106/200] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=75;, score=(train=0.562, test=0.547) total time=   1.3s
# [CV 4/5; 107/200] START criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100
# [CV 4/5; 107/200] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100;, score=(train=0.561, test=0.529) total time=120.0min
# [CV 2/5; 109/200] START criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150
# [CV 2/5; 109/200] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150;, score=(train=0.569, test=0.551) total time=   3.6s
# [CV 4/5; 110/200] START criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=175
# [CV 4/5; 110/200] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=175;, score=(train=0.562, test=0.539) total time=   2.1s
# [CV 2/5; 113/200] START criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=125
# [CV 2/5; 113/200] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=125;, score=(train=0.567, test=0.550) total time=   2.0s
# [CV 5/5; 114/200] START criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150
# [CV 5/5; 114/200] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=(train=0.555, test=0.592) total time=  15.2s
# [CV 3/5; 116/200] START criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75
# [CV 3/5; 116/200] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75;, score=(train=0.561, test=0.547) total time=119.6min
# [CV 4/5; 117/200] START criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100
# [CV 4/5; 117/200] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100;, score=(train=0.562, test=0.528) total time=   1.9s
# [CV 1/5; 119/200] START criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150
# [CV 1/5; 119/200] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150;, score=(train=0.593, test=0.529) total time=   2.1s
# [CV 4/5; 120/200] START criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=175
# [CV 4/5; 120/200] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=175;, score=(train=0.555, test=0.536) total time=   2.0s
# [CV 1/5; 123/200] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=125
# [CV 1/5; 123/200] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=125;, score=(train=0.806, test=0.559) total time=   1.8s
# [CV 4/5; 124/200] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150
# [CV 4/5; 124/200] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=(train=0.761, test=0.732) total time=  28.8s
# [CV 2/5; 126/200] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=75
# [CV 2/5; 126/200] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=75;, score=(train=0.794, test=0.609) total time=103.3min
# [CV 1/5; 127/200] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100
# [CV 1/5; 127/200] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100;, score=(train=0.804, test=0.556) total time=   1.8s
# [CV 4/5; 128/200] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125
# [CV 4/5; 128/200] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125;, score=(train=0.755, test=0.735) total time=   2.8s
# [CV 2/5; 130/200] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=175
# [CV 2/5; 130/200] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=175;, score=(train=0.797, test=0.602) total time=   2.8s
# [CV 1/5; 132/200] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 1/5; 132/200] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.786, test=0.552) total time=  17.8s
# [CV 4/5; 133/200] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=125
# [CV 4/5; 133/200] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=125;, score=(train=0.739, test=0.724) total time=119.8min
# [CV 2/5; 135/200] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=175
# [CV 2/5; 135/200] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=175;, score=(train=0.776, test=0.617) total time=   2.3s
# [CV 1/5; 137/200] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100
# [CV 1/5; 137/200] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100;, score=(train=0.786, test=0.552) total time=   1.4s
# [CV 4/5; 138/200] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125
# [CV 4/5; 138/200] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125;, score=(train=0.739, test=0.724) total time=  17.6s
# [CV 2/5; 140/200] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=175
# [CV 2/5; 140/200] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=175;, score=(train=0.776, test=0.617) total time=63.9min
# [CV 5/5; 141/200] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75
# [CV 5/5; 141/200] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75;, score=(train=0.926, test=0.795) total time=   2.7s
# [CV 3/5; 143/200] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=125
# [CV 3/5; 143/200] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=125;, score=(train=0.926, test=0.762) total time=   3.9s
# [CV 1/5; 145/200] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=175
# [CV 1/5; 145/200] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=175;, score=(train=0.924, test=0.574) total time=   6.3s
# [CV 5/5; 146/200] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=75
# [CV 5/5; 146/200] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=75;, score=(train=0.907, test=0.789) total time=   2.5s
# [CV 2/5; 148/200] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125
# [CV 2/5; 148/200] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125;, score=(train=0.917, test=0.645) total time=   3.4s
# [CV 5/5; 149/200] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150
# [CV 5/5; 149/200] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150;, score=(train=0.907, test=0.798) total time=   5.7s
# [CV 3/5; 151/200] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=75
# [CV 3/5; 151/200] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=75;, score=(train=0.844, test=0.731) total time=   2.5s
# [CV 3/5; 152/200] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 3/5; 152/200] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.843, test=0.731) total time=   3.7s
# [CV 1/5; 154/200] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150
# [CV 1/5; 154/200] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=(train=0.876, test=0.561) total time=   4.6s
# [CV 4/5; 155/200] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=175
# [CV 4/5; 155/200] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=175;, score=(train=0.853, test=0.765) total time=   6.3s
# [CV 1/5; 158/200] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125
# [CV 1/5; 158/200] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125;, score=(train=0.877, test=0.564) total time=   3.8s
# [CV 4/5; 159/200] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150
# [CV 4/5; 159/200] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150;, score=(train=0.851, test=0.765) total time=   5.1s
# [CV 2/5; 161/200] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75
# [CV 2/5; 161/200] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75;, score=(train=0.982, test=0.621) total time=   2.5s
# [CV 3/5; 162/200] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 3/5; 162/200] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.984, test=0.760) total time=   3.9s
# [CV 1/5; 164/200] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150
# [CV 1/5; 164/200] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=(train=0.981, test=0.597) total time=   5.5s
# [CV 4/5; 165/200] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=175
# [CV 4/5; 165/200] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=175;, score=(train=0.982, test=0.803) total time=   6.5s
# [CV 1/5; 168/200] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125
# [CV 1/5; 168/200] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125;, score=(train=0.968, test=0.591) total time=   5.6s
# [CV 4/5; 169/200] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150
# [CV 4/5; 169/200] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150;, score=(train=0.967, test=0.801) total time=   8.1s
# [CV 2/5; 171/200] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=75
# [CV 2/5; 171/200] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=75;, score=(train=0.897, test=0.622) total time=   2.4s
# [CV 2/5; 172/200] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 2/5; 172/200] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.898, test=0.623) total time=   2.7s
# [CV 5/5; 173/200] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=125
# [CV 5/5; 173/200] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=125;, score=(train=0.870, test=0.783) total time=   3.3s
# [CV 3/5; 175/200] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=175
# [CV 3/5; 175/200] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=175;, score=(train=0.872, test=0.730) total time=   4.9s
# [CV 2/5; 177/200] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100
# [CV 2/5; 177/200] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100;, score=(train=0.898, test=0.623) total time=   3.2s
# [CV 5/5; 178/200] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125
# [CV 5/5; 178/200] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125;, score=(train=0.870, test=0.783) total time=   3.8s
# [CV 3/5; 180/200] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=175
# [CV 3/5; 180/200] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=175;, score=(train=0.872, test=0.730) total time=   5.6s
# [CV 4/5; 182/200] START criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 4/5; 182/200] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.997, test=0.803) total time=   3.5s
# [CV 2/5; 184/200] START criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150
# [CV 2/5; 184/200] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=(train=0.998, test=0.613) total time=   5.3s
# [CV 5/5; 185/200] START criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=175
# [CV 5/5; 185/200] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=175;, score=(train=0.995, test=0.795) total time=   7.0s
# [CV 3/5; 188/200] START criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125
# [CV 3/5; 188/200] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125;, score=(train=0.988, test=0.753) total time=   6.1s
# [CV 1/5; 190/200] START criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=175
# [CV 1/5; 190/200] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=175;, score=(train=0.993, test=0.585) total time=   8.1s
# [CV 4/5; 191/200] START criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=75
# [CV 4/5; 191/200] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=75;, score=(train=0.880, test=0.766) total time=   3.0s
# [CV 5/5; 192/200] START criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 5/5; 192/200] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.879, test=0.777) total time=   3.8s
# [CV 3/5; 194/200] START criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150
# [CV 3/5; 194/200] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=(train=0.874, test=0.732) total time=   5.0s
# [CV 1/5; 196/200] START criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75
# [CV 1/5; 196/200] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75;, score=(train=0.902, test=0.567) total time=   3.2s
# [CV 4/5; 196/200] START criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75
# [CV 4/5; 196/200] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75;, score=(train=0.880, test=0.766) total time=   2.3s
# [CV 2/5; 198/200] START criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125
# [CV 2/5; 198/200] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125;, score=(train=0.901, test=0.622) total time=   3.5s
# [CV 5/5; 199/200] START criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150
# [CV 5/5; 199/200] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150;, score=(train=0.878, test=0.778) total time=   5.6s
# [CV 3/5; 82/200] END criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.996, test=0.758) total time=   3.4s
# [CV 1/5; 84/200] START criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150
# [CV 1/5; 84/200] END criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=(train=0.998, test=0.587) total time=   5.7s
# [CV 4/5; 85/200] START criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=175
# [CV 4/5; 85/200] END criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=175;, score=(train=0.997, test=0.798) total time=   6.0s
# [CV 2/5; 88/200] START criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125
# [CV 2/5; 88/200] END criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125;, score=(train=0.993, test=0.619) total time=   4.3s
# [CV 5/5; 89/200] START criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150
# [CV 5/5; 89/200] END criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150;, score=(train=0.987, test=0.797) total time=   5.6s
# [CV 3/5; 91/200] START criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=75
# [CV 3/5; 91/200] END criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=75;, score=(train=0.873, test=0.730) total time=   2.5s
# ...
# [CV 2/5; 121/200] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75
# [CV 2/5; 121/200] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75;, score=(train=0.794, test=0.620) total time=   1.2s
# [CV 2/5; 122/200] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 2/5; 122/200] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.795, test=0.621) total time=   1.5s
# [CV 5/5; 123/200] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=125
# [CV 5/5; 123/200] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=125;, score=(train=0.764, test=0.745) total time=  15.7s
# [CV 3/5; 125/200] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=175
# [CV 3/5; 125/200] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=175;, score=(train=0.766, test=0.703) total time=103.5min
# [CV 3/5; 127/200] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100
# [CV 3/5; 127/200] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100;, score=(train=0.763, test=0.701) total time=   1.1s
# [CV 1/5; 129/200] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150
# [CV 1/5; 129/200] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150;, score=(train=0.804, test=0.553) total time=   3.3s
# [CV 4/5; 130/200] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=175
# [CV 4/5; 130/200] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=175;, score=(train=0.757, test=0.741) total time=   5.5s
# [CV 2/5; 133/200] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=125
# [CV 2/5; 133/200] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=125;, score=(train=0.776, test=0.616) total time=120.0min
# [CV 5/5; 134/200] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150
# [CV 5/5; 134/200] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=(train=0.742, test=0.749) total time=   2.0s
# [CV 3/5; 136/200] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75
# [CV 3/5; 136/200] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75;, score=(train=0.742, test=0.685) total time=   1.7s
# [CV 4/5; 137/200] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100
# [CV 4/5; 137/200] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100;, score=(train=0.740, test=0.718) total time=   1.4s
# [CV 2/5; 139/200] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150
# [CV 2/5; 139/200] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150;, score=(train=0.776, test=0.615) total time=  28.7s
# [CV 5/5; 140/200] START criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=175
# [CV 5/5; 140/200] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=175;, score=(train=0.744, test=0.747) total time=63.7min
# [CV 5/5; 142/200] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 5/5; 142/200] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.926, test=0.795) total time=   3.5s
# [CV 2/5; 144/200] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150
# [CV 2/5; 144/200] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=(train=0.929, test=0.636) total time=   4.4s
# [CV 5/5; 145/200] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=175
# [CV 5/5; 145/200] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=175;, score=(train=0.926, test=0.798) total time=   6.1s
# [CV 3/5; 148/200] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125
# [CV 3/5; 148/200] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125;, score=(train=0.915, test=0.752) total time=   3.4s
# [CV 1/5; 150/200] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=175
# [CV 1/5; 150/200] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=175;, score=(train=0.919, test=0.565) total time=   6.5s
# [CV 4/5; 151/200] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=75
# [CV 4/5; 151/200] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=75;, score=(train=0.851, test=0.768) total time=   2.3s
# [CV 5/5; 152/200] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 5/5; 152/200] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.844, test=0.775) total time=   4.1s
# [CV 3/5; 154/200] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150
# [CV 3/5; 154/200] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=(train=0.847, test=0.726) total time=   4.8s
# [CV 1/5; 156/200] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75
# [CV 1/5; 156/200] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75;, score=(train=0.873, test=0.571) total time=   2.8s
# [CV 5/5; 156/200] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75
# [CV 5/5; 156/200] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75;, score=(train=0.843, test=0.775) total time=   2.7s
# [CV 3/5; 158/200] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125
# [CV 3/5; 158/200] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125;, score=(train=0.847, test=0.734) total time=   3.9s
# [CV 1/5; 160/200] START criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=175
# [CV 1/5; 160/200] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=175;, score=(train=0.876, test=0.556) total time=   5.6s
# [CV 4/5; 161/200] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75
# [CV 4/5; 161/200] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75;, score=(train=0.982, test=0.792) total time=   2.6s
# [CV 2/5; 163/200] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=125
# [CV 2/5; 163/200] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=125;, score=(train=0.982, test=0.622) total time=   5.0s
# [CV 5/5; 164/200] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150
# [CV 5/5; 164/200] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=(train=0.983, test=0.804) total time=   5.8s
# [CV 3/5; 166/200] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=75
# [CV 3/5; 166/200] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=75;, score=(train=0.968, test=0.757) total time=   2.8s
# [CV 2/5; 167/200] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100
# [CV 2/5; 167/200] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100;, score=(train=0.970, test=0.626) total time=   3.4s
# [CV 5/5; 168/200] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125
# [CV 5/5; 168/200] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=125;, score=(train=0.969, test=0.804) total time=   6.9s
# [CV 3/5; 170/200] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=175
# [CV 3/5; 170/200] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=175;, score=(train=0.969, test=0.763) total time=   8.0s
# [CV 4/5; 172/200] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 4/5; 172/200] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.874, test=0.769) total time=   2.7s
# [CV 2/5; 174/200] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150
# [CV 2/5; 174/200] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=(train=0.897, test=0.623) total time=   4.0s
# [CV 5/5; 175/200] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=175
# [CV 5/5; 175/200] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=175;, score=(train=0.872, test=0.774) total time=   5.0s
# [CV 1/5; 178/200] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125
# [CV 1/5; 178/200] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=125;, score=(train=0.900, test=0.562) total time=   3.8s
# [CV 4/5; 179/200] START criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150
# [CV 4/5; 179/200] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150;, score=(train=0.875, test=0.774) total time=   4.4s
# [CV 2/5; 181/200] START criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75
# [CV 2/5; 181/200] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=75;, score=(train=0.997, test=0.617) total time=   3.1s
# [CV 1/5; 182/200] START criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 1/5; 182/200] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.997, test=0.588) total time=   3.3s
# [CV 4/5; 183/200] START criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=125
# [CV 4/5; 183/200] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=125;, score=(train=0.997, test=0.797) total time=   4.5s
# [CV 2/5; 185/200] START criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=175
# [CV 2/5; 185/200] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=175;, score=(train=0.998, test=0.615) total time=   6.6s
# [CV 3/5; 187/200] START criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100
# [CV 3/5; 187/200] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=100;, score=(train=0.987, test=0.749) total time=   3.8s
# [CV 1/5; 189/200] START criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150
# [CV 1/5; 189/200] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=150;, score=(train=0.993, test=0.581) total time=   8.0s
# [CV 4/5; 190/200] START criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=175
# [CV 4/5; 190/200] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=175;, score=(train=0.991, test=0.799) total time=   7.2s
# [CV 2/5; 193/200] START criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=125
# [CV 2/5; 193/200] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=125;, score=(train=0.901, test=0.622) total time=   4.6s
# [CV 5/5; 194/200] START criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150
# [CV 5/5; 194/200] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=(train=0.878, test=0.778) total time=   5.4s
# [CV 3/5; 196/200] START criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75
# [CV 3/5; 196/200] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=75;, score=(train=0.873, test=0.729) total time=   2.7s
# [CV 4/5; 197/200] START criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100
# [CV 4/5; 197/200] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=100;, score=(train=0.878, test=0.771) total time=   3.0s
# [CV 2/5; 199/200] START criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150
# [CV 2/5; 199/200] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=150;, score=(train=0.903, test=0.621) total time=   5.2s
# [CV 5/5; 200/200] START criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=175
# [CV 5/5; 200/200] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=175;, score=(train=0.877, test=0.778) total time=   5.4s

# %% [markdown]
# ##### The parameter
# {'criterion': 'entropy',
#  'max_depth': 20,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 150} was chosen.

# %% [markdown]
# It is the same as before.
