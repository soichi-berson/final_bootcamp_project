# %% [markdown]
# # 4 Tuning the parameter of KNN

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
import pickle

# %%
#load the files

X_train = pd.read_csv('../data/x_y_data/X_resampled.csv')
y_train = pd.read_csv('../data/x_y_data/y_resampled.csv')
X_test = pd.read_csv('../data/x_y_data/X_test.csv')
y_test = pd.read_csv('../data/x_y_data/y_test.csv')
data = pd.read_csv('../data/cleaned_data/cleaned_data.csv')

X_train = np.ascontiguousarray(X_train)
y_train = np.ascontiguousarray(y_train)
X_test = np.ascontiguousarray(X_test)
y_test = np.ascontiguousarray(y_test)

# %%
X_train.shape
# Out:
# (7750, 18)

# %%
param_grid = {
    'n_neighbors': [3, 5, 7],
    'weights': ['uniform', 'distance'],
    'algorithm' : ['auto', 'ball_tree', 'kd_tree', 'brute'] 
    }

knn = KNeighborsClassifier()

grid_search = GridSearchCV(knn, param_grid, cv=5,return_train_score=True,n_jobs=-1, verbose = 20)
grid_search.fit(X_train,y_train)
grid_search.best_params_ #To check the best set of parameters returned
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/neighbors/_classification.py:228: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /Users/soichirotanabe/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/sklearn/neighbors/_classification.py:228: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# ...

# %%
knn1= KNeighborsClassifier(algorithm= 'auto', n_neighbors= 3, weights= 'distance')

results = []
kfold = KFold(n_splits=10, shuffle=False)
cv_results = cross_val_score(knn1, X_train, y_train, cv=kfold, scoring="accuracy")

results.append(cv_results)
    
msg = f" KNN: {cv_results.mean()} ({cv_results.std()})"
print(msg)
# Out:
#  KNN: 0.9278709677419356 (0.05363599518223136)

# %% [markdown]
# By the parameter {'algorithm': 'auto', 'n_neighbors': 3, 'weights': 'distance'}, it reached the mean:0.92.

# %%
names = ["knn"]
results_dict = {name: result for name, result in zip(names, results)}

# Create the DataFrame using the dictionary
score = pd.DataFrame(results_dict)

# Print the DataFrame
display(score)
# Out:
#         knn
# 0  0.870968
# 1  0.870968
# 2  0.886452
# 3  0.846452
# 4  0.905806
# 5  0.972903
# 6  0.979355
# 7  0.984516
# 8  0.979355
# 9  0.981935

# %%
#save the score
score.to_csv('../data/score/best_knn.csv', index=False)

# %%
#save the model
knn1.fit(X_train, y_train)

filename = "../models/knn.pickle" # Path with filename

with open(filename, "wb") as file:
        pickle.dump(knn1,file)

# %%
X_train2 = pd.read_csv('../data/x_y_data/X_resampled.csv')

# %%
X_train2
# Out:
#            age  hypertension  heart_disease  ever_married  avg_glucose_level  \
# 0     1.000000      0.000000       0.000000           1.0           0.936469
# 1     0.759686      0.000000       0.000000           1.0           0.157309
# 2     0.694973      1.000000       1.000000           1.0           0.977329
# 3     0.644004      0.000000       0.000000           1.0           0.379521
# 4     0.669393      0.000000       0.000000           1.0           0.562577
# ...        ...           ...            ...           ...                ...
# 7745  0.667088      0.000000       0.000000           1.0           0.795058
# 7746  0.876189      0.000000       0.000000           1.0           0.600780
# 7747  0.769111      0.559637       0.000000           1.0           0.420485
# 7748  0.813841      1.000000       0.126612           0.0           0.406116
# 7749  0.747499      0.000000       1.000000           1.0           0.663053
#
# ...

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier

# Create the KNeighborsClassifier with the desired parameters
knn1 = KNeighborsClassifier(algorithm='auto', n_neighbors=3, weights='distance')

# Fit the model to the training data
knn1.fit(X_train, y_train)

# Calculate feature relevance using the inverse distances to the k neighbors and their weights
distances, neighbors = knn1.kneighbors(X_train, n_neighbors=knn1.n_neighbors, return_distance=True)

# Calculate feature relevance using the inverse distances to the k neighbors
feature_relevance = knn1.kneighbors(X_train, n_neighbors=knn1.n_neighbors, return_distance=True)[0].sum(axis=0)

# Normalize the relevance values to get importance scores
feature_importance = feature_relevance / feature_relevance.sum()

# Create a DataFrame with feature names and their importance scores
feature_names = X_train2.columns
feature_imp_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importance})

# Sort the DataFrame by importance in descending order
feature_imp_df = feature_imp_df.sort_values(by='Importance', ascending=False)

# Plot the feature importance
plt.figure(figsize=(8, 6))
sns.barplot(x='Importance', y='Feature', data=feature_imp_df, palette='viridis')
plt.xlabel('Feature Importance')
plt.title('KNeighborsClassifier - Feature Importance (Weights=Distance)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 24
#      22 # Create a DataFrame with feature names and their importance scores
#      23 feature_names = X_train2.columns
# ---> 24 feature_imp_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importance})
#      26 # Sort the DataFrame by importance in descending order
#      27 feature_imp_df = feature_imp_df.sort_values(by='Importance', ascending=False)
#
# File ~/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/pandas/core/frame.py:709, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     703     mgr = self._init_mgr(
#     704         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     705     )
#     707 elif isinstance(data, dict):
# ...

# %%
# Check the shapes of X_train and y_train
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)

# Check the shape of feature_importance
print("Feature importance shape:", feature_importance.shape)
# Out:
# X_train shape: (7750, 18)
# y_train shape: (7750, 1)
# Feature importance shape: (3,)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# Load the Iris dataset
data = load_iris()
X = data.data
y = data.target

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# Create the KNeighborsClassifier with the desired parameters
knn1 = KNeighborsClassifier(algorithm='auto', n_neighbors=3, weights='distance')

# Fit the model to the training data
knn1.fit(X_train, y_train)

# Calculate feature relevance using the inverse distances to the k neighbors and their weights
distances, neighbors = knn1.kneighbors(X_train, n_neighbors=knn1.n_neighbors, return_distance=True)
feature_relevance = (1 / distances).sum(axis=0)

# Normalize the relevance values to get importance scores
feature_importance = feature_relevance / feature_relevance.sum()

# Create a DataFrame with feature names and their importance scores
feature_names = data.feature_names
feature_imp_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importance})

# Sort the DataFrame by importance in descending order
feature_imp_df = feature_imp_df.sort_values(by='Importance', ascending=False)

# Plot the feature importance
plt.figure(figsize=(8, 6))
sns.barplot(x='Importance', y='Feature', data=feature_imp_df, palette='viridis')
plt.xlabel('Feature Importance')
plt.title('KNeighborsClassifier - Feature Importance (Weights=Distance)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 32
#      30 # Create a DataFrame with feature names and their importance scores
#      31 feature_names = data.feature_names
# ---> 32 feature_imp_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importance})
#      34 # Sort the DataFrame by importance in descending order
#      35 feature_imp_df = feature_imp_df.sort_values(by='Importance', ascending=False)
#
# File ~/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/pandas/core/frame.py:709, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     703     mgr = self._init_mgr(
#     704         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     705     )
#     707 elif isinstance(data, dict):
# ...

# %%
from sklearn.datasets import load_iris
data = load_iris()
# Calculate feature relevance using the inverse distances to the k neighbors


feature_relevance = knn1.kneighbors(X_train, n_neighbors=knn1.n_neighbors, return_distance=True)[0].sum(axis=0)

# Normalize the relevance values to get importance scores
feature_importance = feature_relevance / feature_relevance.sum()

# Create a DataFrame with feature names and their importance scores
feature_imp_df = pd.DataFrame({'Feature': data.feature_names, 'Importance': feature_importance})

# Sort the DataFrame by importance in descending order
feature_imp_df = feature_imp_df.sort_values(by='Importance', ascending=False)

# Plot the feature importance
plt.figure(figsize=(8, 6))
sns.barplot(x='Importance', y='Feature', data=feature_imp_df, palette='viridis')
plt.xlabel('Feature Importance')
plt.title('KNeighborsClassifier - Feature Importance (No Scaling)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 12
#       9 feature_importance = feature_relevance / feature_relevance.sum()
#      11 # Create a DataFrame with feature names and their importance scores
# ---> 12 feature_imp_df = pd.DataFrame({'Feature': data.feature_names, 'Importance': feature_importance})
#      14 # Sort the DataFrame by importance in descending order
#      15 feature_imp_df = feature_imp_df.sort_values(by='Importance', ascending=False)
#
# File ~/Desktop/IRONHACK/Week_9/Final_project/final_project_env/lib/python3.11/site-packages/pandas/core/frame.py:709, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     703     mgr = self._init_mgr(
#     704         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     705     )
#     707 elif isinstance(data, dict):
# ...

# %%
feature_imp = pd.Series(knn1.feature_importances_,
                        index=X.columns).sort_values(ascending=False)

sns.barplot(x=feature_imp, y=feature_imp.index)
plt.xlabel('Significance Score Of Variables')
plt.ylabel('Variables')
plt.title("Variable Severity Levels")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 feature_imp = pd.Series(knn1.feature_importances_,
#       2                         index=X.columns).sort_values(ascending=False)
#       4 sns.barplot(x=feature_imp, y=feature_imp.index)
#       5 plt.xlabel('Significance Score Of Variables')
#
# AttributeError: 'KNeighborsClassifier' object has no attribute 'feature_importances_'

# %%
data = pd.concat([pd.DataFrame(X_resampled, columns=X.columns), pd.Series(y_resampled_obj, name='Target')], axis=1)

# Calculate feature correlations with the target
correlations = data.corr()['Target'].drop('Target').sort_values(ascending=False)

# Display feature correlations
print(correlations)
